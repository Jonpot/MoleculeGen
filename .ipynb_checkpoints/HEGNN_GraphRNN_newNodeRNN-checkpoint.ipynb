# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset
from rdkit import Chem
from rdkit.Chem import AllChem
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
from torch.utils.data import TensorDataset
from torch.nn.utils.rnn import pad_sequence
import torch.nn.functional as F
from torch_geometric.nn import global_mean_pool
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from models.HEGNN import HEGNN  
from rdkit.Chem import rdMolTransforms
#If using earlier than python3.9 version
from typing import Tuple, List

# %%
# Load the data
train_df = pd.read_csv('Processed/Combined_Training.txt', sep = '\t')
val_df = pd.read_csv('Processed/Combined_Validate.txt', sep = '\t')
test_df =pd.read_csv('Processed/Combined_Test.txt', sep = '\t')

# While testing, only use the first 500 samples
# train_df = train_df.iloc[:500]
# val_df = val_df.iloc[:500]
# test_df = test_df.iloc[:500]

# %%
def balance_datasets(dataframe: pd.DataFrame) -> pd.DataFrame:

    """
    This filters the dataset to have a X:1 ratio of 0 value mols to 1 value mols
    Args:
        dataframe (pd.DataFrame): the dataset dataframe
    Return:
        pd.DataFrame: the filtered dataframe
    
    """
    function_one_df = dataframe[dataframe['Function'] == 1]
    function_zero_df = dataframe[dataframe['Function'] == 0]

    num_function_one = function_one_df.shape[0]

    # Calculate the number of rows to take from 'Function' == 0 (X:1 ratio)
    num_function_zero = min(2 * num_function_one, function_zero_df.shape[0]) #2* 

    balanced_function_zero_df = function_zero_df.sample(n=num_function_zero, random_state=42)
    balanced_train_df = pd.concat([function_one_df, balanced_function_zero_df])

    return balanced_train_df

# %%
train_df = balance_datasets(train_df)
val_df = balance_datasets(val_df)
test_df = balance_datasets(test_df)

# %%
torch.manual_seed(42)
np.random.seed(42)

# %%
map_element_to_one_hot = {
    # Note: Should we be including hydrogen? that can only form one bond
        #1: 0, #hydrogen
        6: 1, #carbon
        7: 2, #nitrogen
        9: 3, #fluorine
        5: 4, #boron
        15: 5, #phosphorous
        8: 6, #oxygen
        17: 7, #chlorine
        16: 8, #sulfur
        35: 9, #bromine
        13: 10, #aluminium
        33: 11, #arsenic
        53: 12, #iodine
        80: 13, #mercury
        14: 14, #silicon
        50: 15, #tin
        83: 16, #bismuth
    }

#inverts map_element_to_one_hot
map_one_hot_to_element = {value: key for key, value in map_element_to_one_hot.items()}

# %%
def encode_atomic_number(atomic_number: int) -> list:
    """
    Encodes the atomic number into one-hot encoding
    """

    element_index = map_element_to_one_hot[atomic_number]
    vector_length = len(map_element_to_one_hot.keys())
    one_hot_encoding = [0 for i in range(vector_length)]
    one_hot_encoding[element_index] = 1
    return one_hot_encoding #, vector_length

# %%
from tqdm import tqdm
class MoleculeDataset(Dataset):
    """
    Custom Dataset for molecule data.

    Args:
        dataframe (pd.DataFrame): DataFrame containing molecule data.
    """
    def __init__(self, dataframe: pd.DataFrame):
        self.data_list = []
        #self.smiles = None
        for idx, row in tqdm(dataframe.iterrows(), total=len(dataframe)):
            smiles = row['SMILE']
            label = row['Function']
            try:
                mol = Chem.MolFromSmiles(smiles)
            except:
                mol = None
                print(f'Failed to process SMILES: {smiles}')
            if mol is None:
                continue
            data = mol_to_graph_data(mol, smiles)
            if data is None:
                print("Data was None")
                continue
            data.y = torch.tensor([label], dtype=torch.float)
            self.data_list.append(data)

    def __len__(self) -> int:
        return len(self.data_list)

    def __getitem__(self, idx: int):
        return self.data_list[idx]

def atom_features(atom):
    """
    Returns a list of atom features.

    Args:
        atom (Chem.Atom): RDKit atom object.

    Returns:
        List[float]: List of features.
    """
    features = []
    atomic_number = atom.GetAtomicNum()
    atomic_number_encoded = encode_atomic_number(atomic_number)
    for val in atomic_number_encoded:
        features.append(val)
    #features.append(atom.GetAtomicNum())
    features.append(atom.GetDegree())
    features.append(atom.GetFormalCharge())
    features.append(atom.GetNumRadicalElectrons())
    features.append(int(atom.GetHybridization()))
    features.append(int(atom.GetIsAromatic()))
    features.append(atom.IsInRing())
    features.append(atom.GetMass())
    # New features
    features.append(get_atomic_radius(atom))    # Atomic radius
    features.append(get_vdw_radius(atom))       # van der Waals radius
    features.append(get_chirality(atom))# Chirality (0, 1, 2)
    features.append(get_electronegativity(atom)) # EN
    return features 


def get_atomic_radius(atom):
    """
    Returns the covalent radius (approximation) of an atom.
    Args:
        atom (Chem.Atom): RDKit atom object.

    Returns:
        float: Covalent radius in Ångstroms.
    """
    covalent_radii = {
        1: 0.31, 6: 0.76, 7: 0.71, 8: 0.66, 9: 0.57, 15: 1.07,
        16: 1.05, 17: 0.99, 35: 1.14, 53: 1.33  # Add more elements as needed
    }
    return covalent_radii.get(atom.GetAtomicNum(), 0.7)  # Default to 0.7 Å

def get_vdw_radius(atom):
    """
    Returns the van der Waals radius (approximation) of an atom.
    Args:
        atom (Chem.Atom): RDKit atom object.

    Returns:
        float: van der Waals radius in Ångstroms.
    """
    vdw_radii = {
        1: 1.2, 6: 1.7, 7: 1.55, 8: 1.52, 9: 1.47, 15: 1.8, 
        16: 1.8, 17: 1.75, 35: 1.85, 53: 1.98  # Add more elements as needed
    }
    return vdw_radii.get(atom.GetAtomicNum(), 1.5)  # Default to 1.5 Å


def get_valence_electrons(atom):
    """
    Returns the number of valence electrons for an atom.
    Args:
        atom (Chem.Atom): RDKit atom object.

    Returns:
        int: Number of valence electrons.
    """
    valence_electrons = {
        1: 1, 6: 4, 7: 5, 8: 6, 9: 7,
        15: 5, 16: 6, 17: 7, 35: 7, 53: 7
    }
    return valence_electrons.get(atom.GetAtomicNum(), 0)

def get_electronegativity(atom):
    """
    Returns the electronegativity of an atom.
    Args:
        atom (Chem.Atom): RDKit atom object.

    Returns:
        float: Electronegativity value.
    """
    electronegativity = {
        1: 2.20, 6: 2.55, 7: 3.04, 8: 3.44, 9: 3.98,
        15: 2.19, 16: 2.58, 17: 3.16, 35: 2.96, 53: 2.66
    }
    return electronegativity.get(atom.GetAtomicNum(), 2.0)

def get_chirality(atom):
    """
    Returns the chirality of an atom as a numeric feature.
    Args:
        atom (Chem.Atom): RDKit atom object.

    Returns:
        int: Chirality encoded as an integer (0: Unspecified, 1: CW, 2: CCW).
    """
    chiral_tag = atom.GetChiralTag()
    if chiral_tag == Chem.rdchem.ChiralType.CHI_TETRAHEDRAL_CW:
        return 1
    elif chiral_tag == Chem.rdchem.ChiralType.CHI_TETRAHEDRAL_CCW:
        return 2
    else:
        return 0  # Unspecified or no chirality



# Function to check molecule validity
def is_valid_molecule(mol):
    """Sanity check for molecule validity after adding hydrogens."""
    try:
        Chem.SanitizeMol(mol)
        return True
    except Exception as e:
        print(f"Sanitization failed: {e}")
        return False


# Function to convert bond types to numeric values 
def bond_type_to_numeric(bond_type): 
     bond_mapping = {'SINGLE': 0, 'DOUBLE': 1, 'TRIPLE': 2, 'AROMATIC': 3} 
     return bond_mapping.get(bond_type, -1) 


# Function to calculate bond angles 
def calc_bond_angle(mol, atom1_idx, atom2_idx): 
     neighbors1 = [nbr.GetIdx() for nbr in mol.GetAtomWithIdx(atom1_idx).GetNeighbors() if nbr.GetIdx() != atom2_idx] 
     neighbors2 = [nbr.GetIdx() for nbr in mol.GetAtomWithIdx(atom2_idx).GetNeighbors() if nbr.GetIdx() != atom1_idx] 
     if neighbors1 and neighbors2: 
         return rdMolTransforms.GetAngleDeg(mol.GetConformer(), neighbors1[0], atom1_idx, atom2_idx)
     return None 


# Function to check if a bond is rotatable 
def is_rotatable_bond(bond): 
     if bond.GetBondType() != Chem.rdchem.BondType.SINGLE:
         return False 
     return (not bond.GetBeginAtom().IsInRing() and bond.GetBeginAtom().GetDegree() > 1 and 
             not bond.GetEndAtom().IsInRing() and bond.GetEndAtom().GetDegree() > 1)


# Conformer generation with fallback 
def generate_conformer(mol, max_attempts=1000): 
     params = AllChem.ETKDG()
     params.maxAttempts = max_attempts
     try: 
         success = AllChem.EmbedMolecule(mol, params)
         if success == -1: 
             return None  # Failed to generate conformer 
         try: 
             AllChem.UFFOptimizeMolecule(mol) 
         except ValueError: 
             if not AllChem.MMFFOptimizeMolecule(mol): 
                 return None 
     except Exception as e: 
         print(f'Conformer generation error: {e}') 
         return None 
     return mol 

def calc_bond_length(mol, atom1_idx, atom2_idx):
    """
    Calculates the bond length (3D distance) between two atoms.
    Args:
        mol (Chem.Mol): RDKit molecule object.
        atom1_idx (int): Index of the first atom.
        atom2_idx (int): Index of the second atom.

    Returns:
        float: Bond length in Ångstroms.
    """
    pos1 = mol.GetConformer().GetAtomPosition(atom1_idx)
    pos2 = mol.GetConformer().GetAtomPosition(atom2_idx)
    return pos1.Distance(pos2)

def calc_bond_polarity(atom1, atom2):
    """
    Calculates the bond polarity based on the electronegativity difference.
    Args:
        atom1 (Chem.Atom): First atom.
        atom2 (Chem.Atom): Second atom.

    Returns:
        float: Bond polarity (absolute electronegativity difference).
    """
    electronegativity = {
        1: 2.20, 6: 2.55, 7: 3.04, 8: 3.44, 9: 3.98,
        15: 2.19, 16: 2.58, 17: 3.16, 35: 2.96, 53: 2.66
    }
    en1 = electronegativity.get(atom1.GetAtomicNum(), 2.0)
    en2 = electronegativity.get(atom2.GetAtomicNum(), 2.0)
    return abs(en1 - en2)

def is_bond_in_ring(bond):
    """
    Checks if a bond is part of a ring.
    Args:
        bond (Chem.Bond): RDKit bond object.

    Returns:
        bool: True if the bond is in a ring, False otherwise.
    """
    return bond.IsInRing()

def is_bond_conjugated(bond):
    """
    Checks if a bond is conjugated.
    Args:
        bond (Chem.Bond): RDKit bond object.

    Returns:
        bool: True if the bond is conjugated, False otherwise.
    """
    return bond.GetIsConjugated()

def get_bond_stereochemistry(bond):
    """
    Retrieves the stereochemistry of a bond.
    Args:
        bond (Chem.Bond): RDKit bond object.

    Returns:
        int: 0 if no stereochemistry, 1 for cis, 2 for trans.
    """
    stereo = bond.GetStereo()
    if stereo == Chem.rdchem.BondStereo.STEREOCIS:
        return 1
    elif stereo == Chem.rdchem.BondStereo.STEREOTRANS:
        return 2
    return 0


def mol_to_graph_data(mol: Chem.Mol, smiles_name) -> Data:
    """
    Converts an RDKit Mol object to a PyTorch Geometric Data object.

    Args:
        mol (Chem.Mol): RDKit molecule object.

    Returns:
        data (Data): PyTorch Geometric Data object.
    """
    # Add hydrogens and generate 3D coordinates
    mol = Chem.AddHs(mol)
    if not is_valid_molecule(mol):  # Validate molecule after adding Hs
        print(f"Invalid molecule after adding hydrogens: {smiles_name}")
        return None
    
    mol = generate_conformer(mol)
    if mol is None:
        return None
    
    # Nodes
    node_feats = []
    node_positions = []
    for atom in mol.GetAtoms():
        node_feats.append(atom_features(atom))
        pos = mol.GetConformer().GetAtomPosition(atom.GetIdx())
        node_positions.append([pos.x, pos.y, pos.z])
    node_feats = torch.tensor(node_feats, dtype=torch.float)
    node_positions = torch.tensor(node_positions, dtype=torch.float)
    
    # Edges
    edge_index = []
    edge_attrs = []
    for bond in mol.GetBonds():
        i = bond.GetBeginAtomIdx()
        j = bond.GetEndAtomIdx()
        edge_index.extend([[i, j], [j, i]])  # Undirected
        
        # Define atom1 and atom2
        atom1 = mol.GetAtomWithIdx(i)
        atom2 = mol.GetAtomWithIdx(j)
        
        bond_type_numeric = bond_type_to_numeric(str(bond.GetBondType()))
        bond_angle = calc_bond_angle(mol, i, j) or 0.0
        bond_length = calc_bond_length(mol, i, j)
        rotatable = is_rotatable_bond(bond)
        polarity = calc_bond_polarity(atom1, atom2)
        in_ring = is_bond_in_ring(bond)
        conjugated = is_bond_conjugated(bond)
        stereo = get_bond_stereochemistry(bond)

        edge_attrs.extend([
            [bond_type_numeric, bond_angle, bond_length, int(rotatable), 
             polarity, int(in_ring), int(conjugated), stereo],
            [bond_type_numeric, bond_angle, bond_length, int(rotatable), 
             polarity, int(in_ring), int(conjugated), stereo]  # Reverse direction
        ])
        
    edge_index = torch.tensor(edge_index, dtype=torch.long).t().contiguous()
    edge_attrs = torch.tensor(edge_attrs, dtype=torch.float)
    
    # Node velocities as small random values
    node_velocities = torch.randn_like(node_positions) * 0.01
    
    data = Data(
        x=node_feats,
        pos=node_positions,
        vel=node_velocities,
        edge_index=edge_index,
        edge_attr=edge_attrs,
        smiles=smiles_name
    )
    return data

# %%
# Create datasets
train_dataset = MoleculeDataset(train_df)
val_dataset = MoleculeDataset(val_df)
test_dataset = MoleculeDataset(test_df)

# Create DataLoaders
batch_size = 8 #was 32
print(f"Number of training samples: {len(train_dataset)}")
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
print(f"Number of validation samples: {len(val_dataset)}")
val_loader = DataLoader(val_dataset, batch_size=batch_size)
print(f"Number of test samples: {len(test_dataset)}")
test_loader = DataLoader(test_dataset, batch_size=batch_size)
# Out:
#   0%|                                                                                                                                                                                         | 0/633 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Create datasets
# ----> 2 train_dataset = MoleculeDataset(train_df)
#       3 val_dataset = MoleculeDataset(val_df)
#       4 test_dataset = MoleculeDataset(test_df)
#
# Cell In[8], line 22, in MoleculeDataset.__init__(self, dataframe)
#      20 if mol is None:
#      21     continue
# ---> 22 data = mol_to_graph_data(mol, smiles)
#      23 if data is None:
#      24     print("Data was None")
#
# Cell In[8], line 294, in mol_to_graph_data(mol, smiles_name)
#     292 node_positions = []
#     293 for atom in mol.GetAtoms():
# --> 294     node_feats.append(atom_features(atom))
#     295     pos = mol.GetConformer().GetAtomPosition(atom.GetIdx())
#     296     node_positions.append([pos.x, pos.y, pos.z])
#
# Cell In[8], line 47, in atom_features(atom)
#      45 features = []
#      46 atomic_number = atom.GetAtomicNum()
# ---> 47 atomic_number_encoded = encode_atomic_number(atomic_number)
#      48 for val in atomic_number_encoded:
#      49     features.append(val)
#
# Cell In[7], line 6, in encode_atomic_number(atomic_number)
#       1 def encode_atomic_number(atomic_number: int) -> list:
#       2     """
#       3     Encodes the atomic number into one-hot encoding
#       4     """
# ----> 6     element_index = map_element_to_one_hot[atomic_number]
#       7     vector_length = len(map_element_to_one_hot.keys())
#       8     one_hot_encoding = [0 for i in range(vector_length)]
#
# KeyError: 1

# %%
# Initialize the HEGNN model and classifier
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Define model parameters
num_layers = 3
mol = Chem.MolFromSmiles('CCO')
node_input_dim = len(atom_features(mol.GetAtomWithIdx(0)))
edge_attr_dim = 8   # Bond type, angle, rotatable, atom1, atom2 and more
hidden_dim = 64
max_ell = 2  # Example value

# Initialize the HEGNN
heg_nn = HEGNN(
    num_layer=num_layers,
    node_input_dim=node_input_dim,
    edge_attr_dim=edge_attr_dim,
    hidden_dim=hidden_dim,
    max_ell=max_ell,
    activation=nn.SiLU(),
    device=device
).to(device)

class HEGNNClassifier(nn.Module):
    """
    Model that combines HEGNN and a linear classifier.

    Args:
        heg_nn (HEGNN): The HEGNN model.
        hidden_dim (int): Dimension of the HEGNN output.
    """
    def __init__(self, heg_nn: HEGNN, hidden_dim: int):
        super(HEGNNClassifier, self).__init__()
        self.heg_nn = heg_nn
        self.classifier = nn.Sequential(
            nn.Linear(3, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )

    def forward(self, data):
        node_feat = data.x
        node_pos = data.pos
        node_vel = data.vel
        edge_index = data.edge_index
        edge_attr = data.edge_attr
        batch = data.batch

        node_embeddings = self.heg_nn(node_feat, node_pos, node_vel, edge_index, edge_attr)
        graph_embeddings = global_mean_pool(node_embeddings, batch)
        out = self.classifier(graph_embeddings)
        return out, graph_embeddings

# Initialize the classifier model
model = HEGNNClassifier(heg_nn, hidden_dim).to(device)

# %%
# Define loss function and optimizer
criterion = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
def train(model: nn.Module, loader: DataLoader) -> float:
    """
    Training loop for one epoch.

    Args:
        model (nn.Module): The model to train.
        loader (DataLoader): DataLoader for training data.

    Returns:
        float: Average loss over the epoch.
    """
    model.train()
    total_loss = 0
    for data in loader:
        data = data.to(device)
        optimizer.zero_grad()
        out, _ = model(data)
        label = data.y.view(-1, 1)
        loss = criterion(out, label)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * data.num_graphs
    return total_loss / len(loader.dataset)

# %%
def evaluate(model: nn.Module, loader: DataLoader) -> Tuple[float, np.ndarray, np.ndarray]:
    """
    Evaluation loop.

    Args:
        model (nn.Module): The model to evaluate.
        loader (DataLoader): DataLoader for validation or test data.

    Returns:
        Tuple[float, np.ndarray, np.ndarray]: Average loss, predictions, and labels.
    """
    model.eval()
    total_loss = 0
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for data in loader:
            data = data.to(device)
            out, _ = model(data)
            label = data.y.view(-1, 1)
            loss = criterion(out, label)
            total_loss += loss.item() * data.num_graphs
            preds = torch.sigmoid(out).cpu().numpy()
            all_preds.extend(preds)
            all_labels.extend(label.cpu().numpy())
    return total_loss / len(loader.dataset), np.array(all_preds), np.array(all_labels)

# %%
def get_accuracy(predictions: np.ndarray, labels: np.ndarray) -> float:
    """
    Converts sigmoid prediction to binary values and computes accuracy

    Args: 
        predictions (np.ndarray): Sigmoid prediction values
        labels (np.ndarray): True binary labels

    Returns:
        float: The accuracy score
    """

    binary_preds = []
    for prediction in predictions:
        if prediction >= .5:
            binary_preds.append(1)
        else:
            binary_preds.append(0)
    binary_preds = np.array(binary_preds)
    accuracy = accuracy_score(binary_preds, labels)

    return accuracy

# %%
# Training loop execution
num_epochs = 15 #was 20 
for epoch in range(1, num_epochs + 1):
    train_loss = train(model, train_loader)
    val_loss, val_preds, val_labels = evaluate(model, val_loader)

    val_accuracy = get_accuracy(val_preds, val_labels)
    
    print(f'Epoch {epoch}, Train Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}')
# Out:
# Epoch 1, Train Loss: 5.4480, Validation Loss: 0.6394, Validation Accuracy: 0.6692
# Epoch 2, Train Loss: 0.6405, Validation Loss: 0.6354, Validation Accuracy: 0.6692
# Epoch 3, Train Loss: 0.6369, Validation Loss: 0.6332, Validation Accuracy: 0.6692
# Epoch 4, Train Loss: 0.6364, Validation Loss: 0.6348, Validation Accuracy: 0.6692
# Epoch 5, Train Loss: 0.6363, Validation Loss: 0.6347, Validation Accuracy: 0.6692
# Epoch 6, Train Loss: 0.6272, Validation Loss: 0.6380, Validation Accuracy: 0.6617
# Epoch 7, Train Loss: 0.6223, Validation Loss: 0.6290, Validation Accuracy: 0.6692
# Epoch 8, Train Loss: 0.6138, Validation Loss: 0.6522, Validation Accuracy: 0.6617
# Epoch 9, Train Loss: 0.6146, Validation Loss: 0.6237, Validation Accuracy: 0.6692
# Epoch 10, Train Loss: 0.6074, Validation Loss: 0.6270, Validation Accuracy: 0.6692
# Epoch 11, Train Loss: 0.6052, Validation Loss: 0.6324, Validation Accuracy: 0.6617
# Epoch 12, Train Loss: 0.6058, Validation Loss: 0.6223, Validation Accuracy: 0.6617
# Epoch 13, Train Loss: 0.6007, Validation Loss: 0.6404, Validation Accuracy: 0.6541
# Epoch 14, Train Loss: 0.6035, Validation Loss: 0.6241, Validation Accuracy: 0.6692
# Epoch 15, Train Loss: 0.5942, Validation Loss: 0.6240, Validation Accuracy: 0.6617

# %%
for val in val_preds:
    if val > .54:
        print(val)
#print(val_preds[0:10])

# %%
def get_embeddings_and_labels(model: nn.Module, loader: DataLoader) -> Tuple[np.ndarray, np.ndarray]:
    """
    Extracts graph embeddings and labels from the model.

    Args:
        model (nn.Module): The trained model.
        loader (DataLoader): DataLoader for the dataset.

    Returns:
        Tuple[np.ndarray, np.ndarray]: Embeddings and labels.
    """
    model.eval()
    embeddings = []
    labels = []
    with torch.no_grad():
        for data in loader:
            data = data.to(device)
            out, graph_embeddings = model(data)
            embeddings.append(graph_embeddings.cpu())
            labels.append(data.y.cpu())
    embeddings = torch.cat(embeddings, dim=0)
    labels = torch.cat(labels, dim=0)
    return embeddings.numpy(), labels.numpy()

# %%
# Get embeddings and labels
train_embeddings, train_labels = get_embeddings_and_labels(model, train_loader) 
val_embeddings, val_labels = get_embeddings_and_labels(model, val_loader)
test_embeddings, test_labels = get_embeddings_and_labels(model, test_loader)

# %%
pca = PCA(n_components=2)
train_pca = pca.fit_transform(train_embeddings)
val_pca = pca.transform(val_embeddings)
test_pca = pca.transform(test_embeddings)

# Remove major outliers for better visualization from PCA and labels
x_mean = np.mean(train_pca[:, 0])
x_std = np.std(train_pca[:, 0])
y_mean = np.mean(train_pca[:, 1])
y_std = np.std(train_pca[:, 1])

# Prune outliers down to 1 standard deviation from the mean
pruned_train_pca = train_pca[(train_pca[:, 0] < x_mean + x_std) & (train_pca[:, 0] > x_mean - x_std) &
                             (train_pca[:, 1] < y_mean + y_std) & (train_pca[:, 1] > y_mean - y_std)]
pruned_train_labels = train_labels[(train_pca[:, 0] < x_mean + x_std) & (train_pca[:, 0] > x_mean - x_std) &
                                   (train_pca[:, 1] < y_mean + y_std) & (train_pca[:, 1] > y_mean - y_std)]

pruned_val_pca = val_pca[(val_pca[:, 0] < x_mean + x_std) & (val_pca[:, 0] > x_mean - x_std) &
                            (val_pca[:, 1] < y_mean + y_std) & (val_pca[:, 1] > y_mean - y_std)]
pruned_val_labels = val_labels[(val_pca[:, 0] < x_mean + x_std) & (val_pca[:, 0] > x_mean - x_std) &
                                (val_pca[:, 1] < y_mean + y_std) & (val_pca[:, 1] > y_mean - y_std)]

pruned_test_pca = test_pca[(test_pca[:, 0] < x_mean + x_std) & (test_pca[:, 0] > x_mean - x_std) &
                            (test_pca[:, 1] < y_mean + y_std) & (test_pca[:, 1] > y_mean - y_std)]
pruned_test_labels = test_labels[(test_pca[:, 0] < x_mean + x_std) & (test_pca[:, 0] > x_mean - x_std) &
                                (test_pca[:, 1] < y_mean + y_std) & (test_pca[:, 1] > y_mean - y_std)]


# Plot PCA embeddings
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
plt.scatter(pruned_train_pca[:, 0], pruned_train_pca[:, 1], c=pruned_train_labels, cmap='coolwarm', s=10)
plt.title('Train Data')
plt.subplot(1, 3, 2)
plt.scatter(pruned_val_pca[:, 0], pruned_val_pca[:, 1], c=pruned_val_labels, cmap='coolwarm', s=10)
plt.title('Validation Data')
plt.subplot(1, 3, 3)
plt.scatter(pruned_test_pca[:, 0], pruned_test_pca[:, 1], c=pruned_test_labels, cmap='coolwarm', s=10)
plt.title('Test Data')
plt.tight_layout()
plt.show()

# %%
# Perform PCA and plot embeddings
from sklearn.decomposition import PCA

# Combine embeddings and labels
all_embeddings = np.concatenate([train_embeddings, val_embeddings, test_embeddings], axis=0)
all_labels = np.concatenate([train_labels, val_labels, test_labels], axis=0)

# Perform PCA
pca = PCA(n_components=3)
pca_result = pca.fit_transform(all_embeddings)

# Prune outliers down to 1 standard deviation from the mean
x_mean = np.mean(pca_result[:, 0])
x_std = np.std(pca_result[:, 0])
y_mean = np.mean(pca_result[:, 1])
y_std = np.std(pca_result[:, 1])
z_mean = np.mean(pca_result[:, 2])
z_std = np.std(pca_result[:, 2])

# Prune outliers down to 1 standard deviation from the mean
pruned_pca_result = pca_result[(pca_result[:, 0] < x_mean + x_std) & (pca_result[:, 0] > x_mean - x_std) &
                               (pca_result[:, 1] < y_mean + y_std) & (pca_result[:, 1] > y_mean - y_std) &
                                 (pca_result[:, 2] < z_mean + z_std) & (pca_result[:, 2] > z_mean - z_std)]
pruned_labels = all_labels[(pca_result[:, 0] < x_mean + x_std) & (pca_result[:, 0] > x_mean - x_std) &
                            (pca_result[:, 1] < y_mean + y_std) & (pca_result[:, 1] > y_mean - y_std) &
                            (pca_result[:, 2] < z_mean + z_std) & (pca_result[:, 2] > z_mean - z_std)]

# Plot PCA
plt.figure(figsize=(8, 6))
scatter = plt.scatter(pruned_pca_result[:, 0], pruned_pca_result[:, 1], c=pruned_labels.squeeze(), cmap='coolwarm', alpha=0.7)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('PCA of Graph Embeddings Colored by Function')
plt.colorbar(scatter, label='Function')
plt.show()

# Also plot PCA2 and PCA3
pca = PCA(n_components=3)
pca_result = pca.fit_transform(all_embeddings)

# Plot PCA
plt.figure(figsize=(8, 6))
scatter = plt.scatter(pruned_pca_result[:, 1], pruned_pca_result[:, 2], c=pruned_labels.squeeze(), cmap='coolwarm', alpha=0.7)
plt.xlabel('PC2')
plt.ylabel('PC3')
plt.title('PCA of Graph Embeddings Colored by Function')
plt.colorbar(scatter, label='Function')
plt.show()

# %%
# Train a linear classifier on the embeddings
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, roc_curve

# Prepare training and test data
X_train = train_embeddings
y_train = train_labels.squeeze()
X_test = test_embeddings
y_test = test_labels.squeeze()

# Train logistic regression
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train, y_train)

# Predict probabilities
y_scores = clf.predict_proba(X_test)[:, 1]

# Compute ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, y_scores)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC - Test Set')
plt.legend(loc='lower right')
plt.show()

# %%
# Evaluate the full model on the test set and plot ROC curve
model.eval()
all_preds = []
all_labels = []
with torch.no_grad():
    for data in test_loader:
        data = data.to(device)
        out, _ = model(data)
        preds = torch.sigmoid(out).cpu().numpy()
        labels = data.y.cpu().numpy()
        all_preds.extend(preds)
        all_labels.extend(labels)

accuracy = get_accuracy(all_preds, all_labels)
print(f"Testing accuracy: {accuracy:.4f}")

# Compute ROC curve and AUC
fpr, tpr, thresholds = roc_curve(all_labels, all_preds)

roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, label=f'Full Model ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC - Full Model')
plt.legend(loc='lower right')
plt.show()
# Out:
# Testing accuracy: 0.6667

# %%
count = 0
for val in all_preds:
    if val > .5:
        #print(val)
        count += 1
#print(preds[0:10])
print(count)
print(len(all_preds))
# Out:
# 0
# 138

# %% [markdown]
# # Time to Decode! Using a GraphRNN approach.

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F

# For graph operations
from torch_geometric.utils import to_networkx, from_networkx

# For processing
import networkx as nx
import numpy as np

# %%
class GraphSequenceDataset(Dataset):
    """
    Dataset class that converts graphs into sequences suitable for GraphRNN.
    """
    def __init__(self, data_list, map_element_to_one_hot):
        self.graph_sequences = []
        self.map_element_to_one_hot = map_element_to_one_hot
        self.atomic_numbers = list(map_element_to_one_hot.keys())
        self.atomic_number_to_idx = {num: idx for idx, num in enumerate(self.atomic_numbers)}
        self.idx_to_atomic_number = {idx: num for num, idx in self.atomic_number_to_idx.items()}

        for data in data_list:
            G = to_networkx(data, to_undirected=True)
            seq_nodes, seq_adj = self.graph_to_sequence(G, data)
            self.graph_sequences.append((seq_nodes, seq_adj, data.smiles))

    def graph_to_sequence(self, G, data):
        """
        Converts a NetworkX graph into a sequence of node indices and adjacency vectors.
        """
        num_nodes = G.number_of_nodes()
        seq_nodes = []
        seq_adj = []

        # Consistent node ordering
        nodes = list(G.nodes())
        node_order = dict(zip(nodes, range(num_nodes)))

        # Node features
        node_features = data.x.numpy()
        one_hot_length = len(self.map_element_to_one_hot)
        for i in range(num_nodes):
            node_idx = nodes[i]
            # Extract the one-hot encoded atomic number from the node features
            one_hot_atomic_number = node_features[node_idx][:one_hot_length]
            atomic_number_idx = np.argmax(one_hot_atomic_number)
            seq_nodes.append(atomic_number_idx)

            # Adjacency vector
            adj_vector = np.zeros(i)
            for j in range(i):
                if G.has_edge(node_idx, nodes[j]):
                    adj_vector[j] = 1
            seq_adj.append(adj_vector)

        return seq_nodes, seq_adj

    def __len__(self):
        return len(self.graph_sequences)

    def __getitem__(self, idx):
        return self.graph_sequences[idx]



# Ensure embeddings are converted to tensors
train_embeddings_tensor = torch.tensor(train_embeddings, dtype=torch.float)

# Trim to only the embeddings of positive samples
trimmed_train_dataset = [data for idx, data in enumerate(train_dataset) if train_labels[idx] == 1]
trimmed_train_embeddings_tensor = train_embeddings_tensor[train_labels == 1]

# Prepare the dataset
graph_sequence_dataset = GraphSequenceDataset(train_dataset.data_list, map_element_to_one_hot)

# Define a collate function
def collate_fn(batch):
    seq_nodes, seq_adj, smiles_list = zip(*batch)

    # Retrieve graph embeddings corresponding to the SMILES strings
    graph_embeddings = []
    for smiles in smiles_list:
        index = [i for i, data in enumerate(train_dataset.data_list) if data.smiles == smiles][0]
        embedding = torch.tensor(train_embeddings[index], dtype=torch.float)
        graph_embeddings.append(embedding)

    graph_embeddings = torch.stack(graph_embeddings).to(device)  # (batch_size, embedding_size)

    return seq_nodes, seq_adj, graph_embeddings

# DataLoader
graph_sequence_loader = DataLoader(
    graph_sequence_dataset,
    batch_size=batch_size,
    shuffle=True,
    collate_fn=collate_fn
)

# %%
class NodeRNN(nn.Module):
    """
    RNN model for generating node atomic numbers.
    """
    def __init__(self, num_atom_types, hidden_size):
        super(NodeRNN, self).__init__()
        self.hidden_size = hidden_size
        self.num_atom_types = num_atom_types

        # Embedding layer to map atomic number indices to embeddings
        self.node_embedding = nn.Embedding(num_atom_types + 1, hidden_size)  # +1 for padding/EOS

        self.gru = nn.GRU(hidden_size, hidden_size, batch_first=True)
        self.node_output_layer = nn.Linear(hidden_size, num_atom_types + 1)  # +1 for padding/EOS

    def forward(self, node_input_idx, hidden):
        # node_input_idx: (batch_size, 1)
        node_embedded = self.node_embedding(node_input_idx)  # (batch_size, 1, hidden_size)
        output, hidden = self.gru(node_embedded, hidden)
        node_logits = self.node_output_layer(output)  # (batch_size, 1, num_atom_types + 1)
        return node_logits, hidden



class EdgeRNN(nn.Module):
    """
    RNN model for processing adjacency vectors.
    """
    def __init__(self, hidden_size):
        super(EdgeRNN, self).__init__()
        self.hidden_size = hidden_size
        self.gru = nn.GRU(1, hidden_size, batch_first=True)

    def forward(self, adjacency_vector, hidden):
        output, hidden = self.gru(adjacency_vector, hidden)
        return output, hidden

# %%
class GraphRNN(nn.Module):
    def __init__(self, num_atom_types, hidden_size, embedding_size):
        super(GraphRNN, self).__init__()
        self.hidden_size = hidden_size
        self.num_atom_types = num_atom_types

        # Embedding layer to map graph embeddings to initial hidden state
        self.embedding_layer = nn.Linear(embedding_size, hidden_size)

        # NodeRNN and EdgeRNN
        self.node_rnn = NodeRNN(num_atom_types, hidden_size)
        self.edge_rnn = EdgeRNN(hidden_size)

        # Output layer for edge predictions
        self.edge_output_layer = nn.Linear(hidden_size, 1)

    def pad_adjacency(self, adj_seq, max_len):
        """ 
        This function pads adjacency vectors to a fixed length.
        """
        padded_adj = torch.zeros((max_len, max_len))
        seq_len = len(adj_seq)
        for i in range(seq_len):
            adj_vector = adj_seq[i]
            padded_adj[i, :len(adj_vector)] = torch.tensor(adj_vector, dtype=torch.float)
        return padded_adj

    def forward(self, seq_nodes, seq_adj, graph_embeddings):
        batch_size = len(seq_nodes)
        seq_len = max(len(s) for s in seq_nodes)

        # Initialize hidden state from graph embeddings
        h0 = self.embedding_layer(graph_embeddings).unsqueeze(0)  # (1, batch_size, hidden_size)

        # Pad node sequences
        node_seqs_padded = nn.utils.rnn.pad_sequence(
            [torch.tensor(s, dtype=torch.long) for s in seq_nodes],
            batch_first=True,
            padding_value=self.num_atom_types  # Padding index
        ).to(device)  # (batch_size, seq_len)

        # Pad adjacency sequences
        adj_padded = [self.pad_adjacency(s, seq_len) for s in seq_adj]
        adj_padded = torch.stack(adj_padded, dim=0).to(device)  # (batch_size, seq_len, seq_len)

        # NodeRNN
        node_hidden = h0
        node_logits_list = []
        for t in range(seq_len):
            node_input = node_seqs_padded[:, t].unsqueeze(1)  # (batch_size, 1)
            node_logits, node_hidden = self.node_rnn(node_input, node_hidden)
            node_logits_list.append(node_logits.squeeze(1))  # (batch_size, num_atom_types + 1)

        # EdgeRNN
        edge_logits_list = []
        for i in range(seq_len):
            edge_hidden = node_hidden
            adj_vectors = adj_padded[:, i, :i+1].unsqueeze(-1)  # (batch_size, i+1, 1)
            edge_output, _ = self.edge_rnn(adj_vectors, edge_hidden)
            edge_logits = self.edge_output_layer(edge_output).squeeze(-1)  # (batch_size, i+1)
            edge_logits_list.append(edge_logits)

        return node_logits_list, edge_logits_list, adj_padded

# %%
# Instantiate the model
num_atom_types = len(map_element_to_one_hot)
hidden_size = 64
embedding_size = train_embeddings.shape[1]  # From the HEGNN embeddings

graph_rnn = GraphRNN(num_atom_types, hidden_size, embedding_size).to(device)

# Define loss functions
node_criterion = nn.CrossEntropyLoss(ignore_index=graph_rnn.num_atom_types)  # Ignore padding index
edge_criterion = nn.BCEWithLogitsLoss()

# Loss function and optimizer
edge_criterion = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(graph_rnn.parameters(), lr=0.001)

def train_graph_rnn(model, data_loader, optimizer, epochs=10):
    model.train()
    for epoch in range(epochs):
        total_loss = 0
        for seq_nodes, seq_adj, graph_embeddings in tqdm(data_loader):
            batch_size = len(seq_nodes)
            optimizer.zero_grad()

            # Move data to device
            graph_embeddings = graph_embeddings.to(device)  # (batch_size, embedding_size)

            # Forward pass
            node_logits_list, edge_logits_list, adj_padded = model(seq_nodes, seq_adj, graph_embeddings)

            # Prepare target node indices
            node_seqs_padded = nn.utils.rnn.pad_sequence(
                [torch.tensor(s, dtype=torch.long) for s in seq_nodes],
                batch_first=True,
                padding_value=graph_rnn.num_atom_types  # Padding index
            ).to(device)  # (batch_size, seq_len)

            # Compute node loss
            node_loss = 0
            for t in range(len(node_logits_list)):
                node_logits = node_logits_list[t]  # (batch_size, num_atom_types + 1)
                node_targets = node_seqs_padded[:, t]  # (batch_size,)
                node_loss += node_criterion(node_logits, node_targets)

            # Compute edge loss
            edge_loss = 0
            seq_len = len(edge_logits_list)
            for i in range(seq_len):
                adj_targets = adj_padded[:, i, :i+1]  # (batch_size, i+1)
                edge_logits = edge_logits_list[i]      # (batch_size, i+1)
                edge_loss += edge_criterion(edge_logits.reshape(-1), adj_targets.reshape(-1))

            loss = node_loss + edge_loss
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        avg_loss = total_loss / len(data_loader)
        print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.4f}")

# Train the model
train_graph_rnn(graph_rnn, graph_sequence_loader, optimizer, epochs=10)
# Out:
#   0%|          | 0/80 [00:00<?, ?it/s]100%|██████████| 80/80 [03:26<00:00,  2.59s/it]
# Epoch 1/10, Loss: 1379.8751
# 100%|██████████| 80/80 [04:37<00:00,  3.47s/it]
# Epoch 2/10, Loss: 553.9350
# 100%|██████████| 80/80 [03:41<00:00,  2.77s/it]
# Epoch 3/10, Loss: 779.6599
# 100%|██████████| 80/80 [02:11<00:00,  1.64s/it]
# Epoch 4/10, Loss: 1870.9626
# 100%|██████████| 80/80 [02:10<00:00,  1.63s/it]
# Epoch 5/10, Loss: 1251.1604
# 100%|██████████| 80/80 [02:26<00:00,  1.83s/it]
# Epoch 6/10, Loss: 554.3678
# 100%|██████████| 80/80 [03:07<00:00,  2.34s/it]
# Epoch 7/10, Loss: 630.5970
# 100%|██████████| 80/80 [04:46<00:00,  3.58s/it]
# Epoch 8/10, Loss: 237.6259
# 100%|██████████| 80/80 [04:22<00:00,  3.28s/it]
# Epoch 9/10, Loss: 592.0067
# 100%|██████████| 80/80 [04:21<00:00,  3.26s/it]
# Epoch 10/10, Loss: 205.9030

# %% [markdown]
# # Woah, it actually trained something. Well, going to try to actually make a molecule now. For science!

# %%
# Get positive embeddings
positive_embeddings = train_embeddings[train_labels.squeeze() == 1]

# Calculate centroid
centroid = np.mean(positive_embeddings, axis=0)
centroid = torch.tensor(centroid, dtype=torch.float).to(device)

# %%
max_valence = {
    1: 1,   # Hydrogen
    5: 3,   # Boron
    6: 4,   # Carbon
    7: 3,   # Nitrogen
    8: 2,   # Oxygen
    9: 1,   # Fluorine
    15: 5,  # Phosphorus
    16: 6,  # Sulfur
    17: 1,  # Chlorine
    35: 1,  # Bromine
    53: 1   # Iodine
}


def generate_graph(model, initial_embedding, max_nodes=20):
    model.eval()
    generated_nodes = []
    generated_adj = []
    atom_valences = []  # Keep track of current valence for each atom

    # Initialize hidden state
    h_t = model.embedding_layer(initial_embedding.unsqueeze(0))  # (1, hidden_size)
    h_t = h_t.unsqueeze(0)  # (1, 1, hidden_size)

    # Start with the padding index or a start token
    node_input = torch.tensor([[model.num_atom_types]], dtype=torch.long).to(device)  # (1, 1)

    for i in range(max_nodes):
        # NodeRNN step
        node_logits, h_t = model.node_rnn(node_input, h_t)  # (1, 1, num_atom_types + 1)
        node_prob = F.softmax(node_logits.squeeze(1), dim=-1)  # (1, num_atom_types + 1)
        node_pred = torch.multinomial(node_prob, num_samples=1)  # (1, 1)
        atomic_number_idx = node_pred.item()

        if atomic_number_idx == model.num_atom_types:  # EOS token
            break

        atomic_num = map_one_hot_to_element[atomic_number_idx]
        max_atom_valence = max_valence.get(atomic_num, 4)  # Default to 4 if unknown
        atom_valences.append(0)  # Initialize current valence to 0

        generated_nodes.append(atomic_number_idx)

        # EdgeRNN generation
        edge_hidden = h_t
        adj_vector = []
        for j in range(i+1):
            can_add_edge = True
            if atom_valences[j] >= max_atom_valence:
                can_add_edge = False
            if atom_valences[j] >= max_valence.get(map_one_hot_to_element[generated_nodes[j]], 4):
                can_add_edge = False
            if i == j:
                can_add_edge = False

            if can_add_edge:
                if j == 0:
                    edge_input = torch.zeros(1, 1, 1).to(device)  # Start with zero
                else:
                    edge_input = edge_pred.view(1, 1, 1)
                edge_output, edge_hidden = model.edge_rnn(edge_input, edge_hidden)
                edge_logit = model.edge_output_layer(edge_output)
                edge_prob = torch.sigmoid(edge_logit)
                edge_pred = torch.bernoulli(edge_prob)
                edge_exists = edge_pred.item()
            else:
                edge_exists = 0 # Cannot add edge due to valence constraints

            # Update valence constraints
            if edge_exists:
                atom_valences[j] += 1
                atom_valences[i] += 1

                adj_vector.append(int(edge_pred.item()))
        generated_adj.append(adj_vector)

        # Prepare for next iteration
        node_input = node_pred

    return generated_nodes, generated_adj

# %%
def display_generated_graph(generated_graph):
    # Display the generated graph
    plt.figure(figsize=(8, 6))
    pos = nx.spring_layout(generated_graph)
    nx.draw(generated_graph, pos, with_labels=True, node_size=500, font_size=10, font_color='white')
    plt.title('Generated Graph')
    plt.show()

    print(generated_graph)

# %%
def get_molecule_from_generated_graph(generated_graph: nx.Graph) -> Chem.RWMol:
    """
    Traverses nodes of generated graph to create molecule
    """
    molecule = Chem.RWMol()
    node_to_idx = dict()

    graph_data = generated_graph.nodes.data()
    for node in graph_data: #traverses in order
        #print(node)
        #print(node[1])
        node_features_dict = node[1]
        atomic_number = node_features_dict["atomic_num"]
        #print(atomic_number)
        atom = Chem.Atom(atomic_number)
        idx = molecule.AddAtom(atom)
        node_to_idx[node[0]] = idx

    for edge in generated_graph.edges():
        node1, node2 = edge
        bond_type = Chem.BondType.SINGLE
        molecule.AddBond(node_to_idx[node1], node_to_idx[node2], bond_type)

    return molecule

# %%
def reconstruct_graph(generated_nodes, generated_adj, idx_to_atomic_number):
    G = nx.Graph()
    num_nodes = len(generated_nodes)
    for i in range(num_nodes):
        atomic_number = idx_to_atomic_number[generated_nodes[i]]
        G.add_node(i, atomic_num=atomic_number)
    for i, adj_vector in enumerate(generated_adj):
        for j, edge_exists in enumerate(adj_vector):
            if edge_exists == 1 and not G.has_edge(i, j):
                G.add_edge(i, j)

    # Prune to the largest connected component
    try:
        largest_cc = max(nx.connected_components(G), key=len)
    except ValueError:
        # No connected components
        return None
    G = G.subgraph(largest_cc).copy()
    return G

# %%
def has_carbon(molecule: Chem.RWMol) -> bool:
    for atom in molecule.GetAtoms():
        if atom.GetSymbol() == "C":
            return True
    return False

# %%
import warnings
from rdkit.Chem import Draw
from rdkit.Chem import SanitizeMol, SanitizeFlags

def create_valid_molecule(organic_prob):
    # Sample around the centroid
    sampled_embedding = centroid + torch.randn_like(centroid) * 0.1  # Small perturbation
    molecule = None
    count = 0
    while molecule == None:
        # Generate graph
        gen_nodes, gen_adj = generate_graph(graph_rnn, sampled_embedding)

        # Reconstruct the graph
        generated_graph = reconstruct_graph(gen_nodes, gen_adj, graph_sequence_dataset.idx_to_atomic_number)
        if generated_graph is None:
            count += 1
            continue
        #Display generated graph (optional)
        #display_generated_graph(generated_graph)

        generated_mol = get_molecule_from_generated_graph(generated_graph)
        #Not the correct check we want
        #try:
        #    Chem.SanitizeMol(generated_mol, sanitizeOps=SanitizeFlags.SANITIZE_ALL)
        #except ValueError as e:
        #    print(f"Invalid molecule: {e}")
            #continue
        try:
            #smiles = Chem.MolToSmiles(generated_mol)
            # Suppress warnings
            with warnings.catch_warnings():
                warnings.simplefilter("ignore")
                smiles = Chem.MolToSmiles(generated_mol)
        except:
            count += 1
            continue
        #if length of SMILES is <= 3, we shouldn't count it and set molecule to None
        if len(smiles) <= 3:
            continue


        #Need to see if smiles is chemically reasonable
        mol = Chem.MolFromSmiles(smiles)
        if mol is None:
            pass
            count += 1
            #print(f'Chemically invalid SMILES: {smiles}')
        else:
            #We want to enforce more organic molecules if valid SMILES
            enforce_organic_mol = np.random.random() < organic_prob
            if enforce_organic_mol and has_carbon(generated_mol) == False:
                continue
            print(f"Valid molecule SMILES: {smiles}")
            molecule = mol
            count += 1

    img = Draw.MolToImage(molecule)
    #img.show()
    print(f"Took {count} tries")

    return mol, smiles

# %%
set_of_new_mols = set()
set_of_new_smiles = set()

while len(set_of_new_mols) != 100:
    mol, smiles = create_valid_molecule(.9)
    set_of_new_mols.add(mol)
    set_of_new_smiles.add(smiles)
# Out:
# [16:16:08] Explicit valence for atom # 1 N, 5, is greater than permitted
# [16:16:08] Explicit valence for atom # 1 C, 13, is greater than permitted
# [16:16:08] Explicit valence for atom # 1 Cl, 13, is greater than permitted
# [16:16:08] Explicit valence for atom # 1 C, 8, is greater than permitted
# [16:16:08] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:16:08] Explicit valence for atom # 1 O, 6, is greater than permitted
# [16:16:09] Explicit valence for atom # 1 O, 12, is greater than permitted
# [16:16:09] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:16:09] Explicit valence for atom # 1 O, 4, is greater than permitted
# [16:16:09] Explicit valence for atom # 1 F, 9, is greater than permitted
# [16:16:09] Explicit valence for atom # 1 O, 9, is greater than permitted
# Valid molecule SMILES: C1C2CC12
# Took 10 tries
# Valid molecule SMILES: O1OOO1
# Took 3 tries
# [16:16:09] Explicit valence for atom # 1 O, 12, is greater than permitted
# [16:16:09] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:16:09] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:16:09] Explicit valence for atom # 1 O, 8, is greater than permitted
# [16:16:09] Explicit valence for atom # 1 C, 8, is greater than permitted
# [16:16:10] Explicit valence for atom # 1 H, 18, is greater than permitted
# [16:16:10] Explicit valence for atom # 0 B, 9, is greater than permitted
# [16:16:10] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:16:10] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:16:10] Explicit valence for atom # 1 O, 3, is greater than permitted
# [16:16:10] Explicit valence for atom # 1 O, 14, is greater than permitted
# [16:16:10] Explicit valence for atom # 0 O, 3, is greater than permitted
# [16:16:10] Explicit valence for atom # 0 P, 9, is greater than permitted
# [16:16:10] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:16:10] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:16:10] Explicit valence for atom # 1 O, 3, is greater than permitted
# [16:16:10] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:16:10] WARNING: not removing hydrogen atom without neighbors
# [16:16:11] Explicit valence for atom # 1 O, 6, is greater than permitted
# [16:16:11] Explicit valence for atom # 1 Br, 15, is greater than permitted
# [16:16:11] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:16:11] Explicit valence for atom # 1 C, 5, is greater than permitted
# [16:16:11] Explicit valence for atom # 1 O, 3, is greater than permitted
# [16:16:11] Explicit valence for atom # 1 Cl, 17, is greater than permitted
# [16:16:11] Explicit valence for atom # 1 Br, 13, is greater than permitted
# [16:16:11] Explicit valence for atom # 1 N, 8, is greater than permitted
# [16:16:11] Explicit valence for atom # 1 O, 16, is greater than permitted
# [16:16:11] Explicit valence for atom # 1 Cl, 11, is greater than permitted
# [16:16:11] Explicit valence for atom # 1 O, 11, is greater than permitted
# [16:16:11] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:16:11] Explicit valence for atom # 1 O, 4, is greater than permitted
# [16:16:11] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:16:11] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:16:11] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:16:12] Explicit valence for atom # 1 C, 15, is greater than permitted
# [16:16:12] Explicit valence for atom # 1 Br, 4, is greater than permitted
# [16:16:12] Explicit valence for atom # 1 O, 5, is greater than permitted
# [16:16:12] Explicit valence for atom # 1 I, 12, is greater than permitted
# [16:16:12] Explicit valence for atom # 1 O, 13, is greater than permitted
# [16:16:12] Explicit valence for atom # 1 C, 5, is greater than permitted
# [16:16:12] Explicit valence for atom # 1 O, 13, is greater than permitted
# [16:16:12] Explicit valence for atom # 1 O, 13, is greater than permitted
# [16:16:12] Explicit valence for atom # 1 O, 7, is greater than permitted
# [16:16:12] Explicit valence for atom # 1 C, 10, is greater than permitted
# [16:16:12] Explicit valence for atom # 1 Br, 14, is greater than permitted
# [16:16:12] Explicit valence for atom # 1 C, 8, is greater than permitted
# [16:16:12] Explicit valence for atom # 1 C, 15, is greater than permitted
# [16:16:13] Explicit valence for atom # 1 C, 10, is greater than permitted
# [16:16:13] Explicit valence for atom # 1 C, 8, is greater than permitted
# [16:16:13] Explicit valence for atom # 1 N, 8, is greater than permitted
# [16:16:13] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# [16:16:13] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# [16:16:13] Explicit valence for atom # 1 H, 5, is greater than permitted
# [16:16:13] Explicit valence for atom # 1 S, 19, is greater than permitted
# [16:16:13] Explicit valence for atom # 1 F, 6, is greater than permitted
# [16:16:13] Explicit valence for atom # 1 O, 5, is greater than permitted
# [16:16:13] Explicit valence for atom # 0 Cl, 9, is greater than permitted
# [16:16:13] Explicit valence for atom # 1 C, 8, is greater than permitted
# [16:16:13] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:16:13] Explicit valence for atom # 1 O, 13, is greater than permitted
# [16:16:13] Explicit valence for atom # 1 C, 10, is greater than permitted
# [16:16:13] Explicit valence for atom # 1 O, 10, is greater than permitted
# [16:16:14] Explicit valence for atom # 0 Cl, 9, is greater than permitted
# [16:16:14] Explicit valence for atom # 1 O, 15, is greater than permitted
# [16:16:14] Explicit valence for atom # 1 C, 13, is greater than permitted
# [16:16:14] Explicit valence for atom # 1 C, 5, is greater than permitted
# [16:16:14] Explicit valence for atom # 1 O, 12, is greater than permitted
# [16:16:14] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:16:14] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:16:14] Explicit valence for atom # 0 F, 4, is greater than permitted
# [16:16:14] Explicit valence for atom # 1 C, 17, is greater than permitted
# [16:16:14] Explicit valence for atom # 1 F, 8, is greater than permitted
# [16:16:14] Explicit valence for atom # 1 F, 10, is greater than permitted
# [16:16:14] Explicit valence for atom # 1 C, 18, is greater than permitted
# [16:16:14] Explicit valence for atom # 1 C, 6, is greater than permitted
# [16:16:15] Explicit valence for atom # 1 O, 10, is greater than permitted
# [16:16:15] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:16:15] Explicit valence for atom # 0 P, 11, is greater than permitted
# [16:16:15] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:16:15] Explicit valence for atom # 1 Br, 8, is greater than permitted
# [16:16:15] Explicit valence for atom # 1 O, 10, is greater than permitted
# [16:16:15] Explicit valence for atom # 1 P, 10, is greater than permitted
# [16:16:15] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:16:15] Explicit valence for atom # 0 B, 9, is greater than permitted
# [16:16:15] Explicit valence for atom # 1 O, 5, is greater than permitted
# [16:16:15] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:16:15] Explicit valence for atom # 1 O, 11, is greater than permitted
# [16:16:15] Explicit valence for atom # 0 B, 6, is greater than permitted
# [16:16:15] Explicit valence for atom # 1 I, 13, is greater than permitted
# [16:16:15] Explicit valence for atom # 1 Si, 8, is greater than permitted
# [16:16:15] Explicit valence for atom # 1 C, 9, is greater than permitted
# Valid molecule SMILES: N[SiH2]Br
# Took 87 tries
# [16:16:15] Explicit valence for atom # 1 O, 16, is greater than permitted
# [16:16:16] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:16:16] Explicit valence for atom # 1 C, 13, is greater than permitted
# Valid molecule SMILES: CC(C)[AsH2]
# Took 6 tries
# [16:16:16] Explicit valence for atom # 1 O, 16, is greater than permitted
# [16:16:16] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:16:16] Explicit valence for atom # 1 N, 15, is greater than permitted
# [16:16:16] Explicit valence for atom # 1 O, 17, is greater than permitted
# [16:16:16] Explicit valence for atom # 0 Bi, 12, is greater than permitted
# [16:16:16] Explicit valence for atom # 1 O, 19, is greater than permitted
# [16:16:16] Explicit valence for atom # 1 Cl, 11, is greater than permitted
# [16:16:16] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:16:16] Explicit valence for atom # 1 C, 8, is greater than permitted
# [16:16:17] Explicit valence for atom # 1 O, 7, is greater than permitted
# [16:16:17] Explicit valence for atom # 1 O, 11, is greater than permitted
# [16:16:17] Explicit valence for atom # 1 O, 15, is greater than permitted
# [16:16:17] Explicit valence for atom # 1 S, 17, is greater than permitted
# [16:16:17] Explicit valence for atom # 1 N, 9, is greater than permitted
# Valid molecule SMILES: [SiH4]
# Took 17 tries
# [16:16:17] Explicit valence for atom # 2 Bi, 9, is greater than permitted
# [16:16:18] Explicit valence for atom # 1 C, 13, is greater than permitted
# [16:16:18] Explicit valence for atom # 1 O, 8, is greater than permitted
# [16:16:18] Explicit valence for atom # 1 Br, 2, is greater than permitted
# [16:16:18] Explicit valence for atom # 1 O, 12, is greater than permitted
# [16:16:18] Explicit valence for atom # 1 C, 15, is greater than permitted
# [16:16:18] Explicit valence for atom # 1 O, 6, is greater than permitted
# [16:16:19] Explicit valence for atom # 0 F, 10, is greater than permitted
# [16:16:19] Explicit valence for atom # 9 Cl, 2, is greater than permitted
# [16:16:19] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:16:19] Explicit valence for atom # 1 I, 9, is greater than permitted
# [16:16:19] Explicit valence for atom # 1 C, 7, is greater than permitted
# [16:16:19] Explicit valence for atom # 1 C, 5, is greater than permitted
# [16:16:19] Explicit valence for atom # 0 Cl, 7, is greater than permitted
# [16:16:19] Explicit valence for atom # 1 C, 8, is greater than permitted
# [16:16:20] Explicit valence for atom # 1 C, 6, is greater than permitted
# [16:16:20] Explicit valence for atom # 1 C, 8, is greater than permitted
# [16:16:20] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# [16:16:20] Explicit valence for atom # 1 O, 4, is greater than permitted
# [16:16:20] Explicit valence for atom # 0 Si, 10, is greater than permitted
# [16:16:20] Explicit valence for atom # 1 C, 8, is greater than permitted
# [16:16:20] Explicit valence for atom # 1 Sn, 6, is greater than permitted
# [16:16:20] Explicit valence for atom # 1 O, 6, is greater than permitted
# [16:16:20] Explicit valence for atom # 1 S, 8, is greater than permitted
# [16:16:20] Explicit valence for atom # 1 C, 17, is greater than permitted
# [16:16:20] Explicit valence for atom # 1 O, 11, is greater than permitted
# [16:16:20] Explicit valence for atom # 1 O, 7, is greater than permitted
# [16:16:20] Explicit valence for atom # 1 As, 16, is greater than permitted
# [16:16:20] Explicit valence for atom # 1 C, 11, is greater than permitted
# [16:16:20] Explicit valence for atom # 0 Al, 10, is greater than permitted
# [16:16:21] Explicit valence for atom # 1 S, 14, is greater than permitted
# [16:16:21] Explicit valence for atom # 1 I, 17, is greater than permitted
# [16:16:21] Explicit valence for atom # 1 C, 13, is greater than permitted
# [16:16:21] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:16:21] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:16:21] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:16:21] Explicit valence for atom # 1 N, 13, is greater than permitted
# [16:16:21] Explicit valence for atom # 1 O, 15, is greater than permitted
# [16:16:21] Explicit valence for atom # 1 C, 15, is greater than permitted
# [16:16:21] Explicit valence for atom # 1 F, 5, is greater than permitted
# [16:16:22] Explicit valence for atom # 1 O, 6, is greater than permitted
# [16:16:22] Explicit valence for atom # 1 C, 13, is greater than permitted
# [16:16:22] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:16:22] Explicit valence for atom # 1 C, 13, is greater than permitted
# [16:16:22] Explicit valence for atom # 1 O, 12, is greater than permitted
# [16:16:22] Explicit valence for atom # 1 O, 8, is greater than permitted
# [16:16:23] Explicit valence for atom # 1 F, 7, is greater than permitted
# [16:16:23] Explicit valence for atom # 1 C, 8, is greater than permitted
# [16:16:23] Explicit valence for atom # 1 C, 10, is greater than permitted
# [16:16:23] Explicit valence for atom # 1 O, 15, is greater than permitted
# [16:16:23] Explicit valence for atom # 1 C, 5, is greater than permitted
# [16:16:23] Explicit valence for atom # 1 O, 10, is greater than permitted
# [16:16:23] Explicit valence for atom # 1 S, 14, is greater than permitted
# [16:16:24] WARNING: not removing hydrogen atom without neighbors
# [16:16:24] Explicit valence for atom # 0 O, 7, is greater than permitted
# [16:16:24] Explicit valence for atom # 1 C, 10, is greater than permitted
# [16:16:24] Explicit valence for atom # 1 H, 6, is greater than permitted
# [16:16:24] Explicit valence for atom # 1 C, 15, is greater than permitted
# [16:16:24] Explicit valence for atom # 1 C, 15, is greater than permitted
# [16:16:24] Explicit valence for atom # 0 F, 8, is greater than permitted
# [16:16:24] Explicit valence for atom # 1 O, 4, is greater than permitted
# [16:16:25] Explicit valence for atom # 1 O, 13, is greater than permitted
# [16:16:25] Explicit valence for atom # 1 O, 6, is greater than permitted
# [16:16:25] Explicit valence for atom # 1 O, 17, is greater than permitted
# [16:16:25] Explicit valence for atom # 1 O, 13, is greater than permitted
# [16:16:25] Explicit valence for atom # 0 Si, 10, is greater than permitted
# [16:16:26] Explicit valence for atom # 1 O, 11, is greater than permitted
# [16:16:26] Explicit valence for atom # 0 S, 9, is greater than permitted
# [16:16:26] Explicit valence for atom # 1 Si, 16, is greater than permitted
# [16:16:26] Explicit valence for atom # 1 F, 4, is greater than permitted
# [16:16:26] Explicit valence for atom # 1 O, 17, is greater than permitted
# [16:16:26] Explicit valence for atom # 1 C, 17, is greater than permitted
# [16:16:26] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:16:26] Explicit valence for atom # 1 Sn, 16, is greater than permitted
# [16:16:27] Explicit valence for atom # 1 N, 16, is greater than permitted
# [16:16:27] Explicit valence for atom # 2 O, 5, is greater than permitted
# [16:16:27] Explicit valence for atom # 1 F, 4, is greater than permitted
# [16:16:27] Explicit valence for atom # 1 H, 4, is greater than permitted
# [16:16:27] Explicit valence for atom # 1 S, 8, is greater than permitted
# [16:16:27] Explicit valence for atom # 1 C, 8, is greater than permitted
# [16:16:27] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:16:27] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:16:27] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:16:27] Explicit valence for atom # 1 H, 3, is greater than permitted
# [16:16:28] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:16:28] Explicit valence for atom # 1 C, 17, is greater than permitted
# [16:16:28] Explicit valence for atom # 1 O, 6, is greater than permitted
# [16:16:28] Explicit valence for atom # 1 O, 5, is greater than permitted
# [16:16:28] Explicit valence for atom # 0 I, 9, is greater than permitted
# [16:16:28] Explicit valence for atom # 1 O, 13, is greater than permitted
# [16:16:28] Explicit valence for atom # 1 O, 15, is greater than permitted
# [16:16:28] Explicit valence for atom # 1 O, 3, is greater than permitted
# Valid molecule SMILES: CC1(C)CC1
# Took 94 tries
# [16:16:29] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [16:16:29] Explicit valence for atom # 10 Cl, 2, is greater than permitted
# [16:16:29] Explicit valence for atom # 1 C, 18, is greater than permitted
# Valid molecule SMILES: C1C23CC12C3
# Took 3 tries
# [16:16:29] Explicit valence for atom # 1 C, 10, is greater than permitted
# [16:16:29] Explicit valence for atom # 1 C, 10, is greater than permitted
# [16:16:30] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:16:30] Explicit valence for atom # 1 C, 15, is greater than permitted
# [16:16:30] Explicit valence for atom # 1 O, 5, is greater than permitted
# [16:16:30] Explicit valence for atom # 1 O, 6, is greater than permitted
# [16:16:30] Explicit valence for atom # 1 C, 11, is greater than permitted
# [16:16:30] Explicit valence for atom # 1 C, 15, is greater than permitted
# [16:16:30] Explicit valence for atom # 1 O, 8, is greater than permitted
# [16:16:30] Explicit valence for atom # 1 O, 8, is greater than permitted
# [16:16:31] Explicit valence for atom # 0 O, 4, is greater than permitted
# Valid molecule SMILES: [H][SnH]
# Took 13 tries
# [16:16:31] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:16:31] Explicit valence for atom # 1 C, 5, is greater than permitted
# [16:16:31] Explicit valence for atom # 1 O, 9, is greater than permitted
# [16:16:31] Explicit valence for atom # 1 C, 7, is greater than permitted
# [16:16:31] Explicit valence for atom # 1 O, 13, is greater than permitted
# [16:16:31] Explicit valence for atom # 1 Si, 17, is greater than permitted
# [16:16:32] Explicit valence for atom # 1 O, 14, is greater than permitted
# [16:16:32] Explicit valence for atom # 1 C, 10, is greater than permitted
# Valid molecule SMILES: N1C23NC12[AsH]3
# Took 10 tries
# [16:16:32] Explicit valence for atom # 1 N, 17, is greater than permitted
# [16:16:32] Explicit valence for atom # 1 C, 11, is greater than permitted
# [16:16:32] Explicit valence for atom # 0 I, 10, is greater than permitted
# [16:16:32] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:16:32] Explicit valence for atom # 1 S, 7, is greater than permitted
# [16:16:33] Explicit valence for atom # 1 C, 8, is greater than permitted
# [16:16:33] Explicit valence for atom # 1 I, 18, is greater than permitted
# [16:16:33] Explicit valence for atom # 8 S, 9, is greater than permitted
# [16:16:33] Explicit valence for atom # 1 C, 15, is greater than permitted
# [16:16:33] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:16:33] Explicit valence for atom # 1 O, 16, is greater than permitted
# [16:16:33] Explicit valence for atom # 1 O, 4, is greater than permitted
# [16:16:33] Explicit valence for atom # 1 O, 14, is greater than permitted
# [16:16:33] Explicit valence for atom # 1 F, 9, is greater than permitted
# [16:16:33] Explicit valence for atom # 1 F, 5, is greater than permitted
# [16:16:34] Explicit valence for atom # 1 Cl, 4, is greater than permitted
# [16:16:34] Explicit valence for atom # 1 C, 6, is greater than permitted
# [16:16:34] Explicit valence for atom # 2 O, 10, is greater than permitted
# Valid molecule SMILES: C1C23CC14C2C34
# Took 19 tries
# [16:16:34] Explicit valence for atom # 1 F, 4, is greater than permitted
# [16:16:35] Explicit valence for atom # 1 N, 9, is greater than permitted
# [16:16:35] Explicit valence for atom # 1 S, 17, is greater than permitted
# [16:16:35] Explicit valence for atom # 1 F, 5, is greater than permitted
# [16:16:35] Explicit valence for atom # 1 O, 12, is greater than permitted
# [16:16:35] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# [16:16:35] Explicit valence for atom # 1 O, 19, is greater than permitted
# [16:16:35] Explicit valence for atom # 2 Bi, 9, is greater than permitted
# [16:16:35] Explicit valence for atom # 1 O, 9, is greater than permitted
# [16:16:35] Explicit valence for atom # 1 O, 17, is greater than permitted
# [16:16:35] Explicit valence for atom # 1 O, 7, is greater than permitted
# [16:16:35] Explicit valence for atom # 1 I, 13, is greater than permitted
# [16:16:35] Explicit valence for atom # 1 O, 6, is greater than permitted
# [16:16:35] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:16:36] Explicit valence for atom # 1 S, 16, is greater than permitted
# [16:16:36] Explicit valence for atom # 2 C, 16, is greater than permitted
# [16:16:36] Explicit valence for atom # 1 O, 3, is greater than permitted
# [16:16:36] Explicit valence for atom # 1 C, 10, is greater than permitted
# [16:16:36] Explicit valence for atom # 1 H, 12, is greater than permitted
# [16:16:37] Explicit valence for atom # 1 O, 13, is greater than permitted
# [16:16:37] Explicit valence for atom # 0 Cl, 9, is greater than permitted
# [16:16:37] Explicit valence for atom # 1 O, 8, is greater than permitted
# Valid molecule SMILES: CC1C23CC1(C2)C3
# Took 23 tries
# [16:16:37] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:16:37] Explicit valence for atom # 1 O, 3, is greater than permitted
# [16:16:37] Explicit valence for atom # 1 O, 5, is greater than permitted
# [16:16:38] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:16:38] Explicit valence for atom # 1 O, 7, is greater than permitted
# [16:16:38] Explicit valence for atom # 1 P, 11, is greater than permitted
# [16:16:38] Explicit valence for atom # 1 O, 18, is greater than permitted
# [16:16:38] Explicit valence for atom # 1 C, 11, is greater than permitted
# [16:16:38] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:16:39] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:16:39] Explicit valence for atom # 1 H, 3, is greater than permitted
# [16:16:39] Explicit valence for atom # 1 Si, 15, is greater than permitted
# [16:16:39] Explicit valence for atom # 0 O, 10, is greater than permitted
# [16:16:39] Explicit valence for atom # 0 B, 15, is greater than permitted
# [16:16:39] Explicit valence for atom # 2 C, 9, is greater than permitted
# [16:16:40] Explicit valence for atom # 1 N, 10, is greater than permitted
# [16:16:40] Explicit valence for atom # 1 H, 4, is greater than permitted
# [16:16:40] Explicit valence for atom # 1 O, 7, is greater than permitted
# [16:16:40] Explicit valence for atom # 1 C, 17, is greater than permitted
# [16:16:40] Explicit valence for atom # 1 F, 6, is greater than permitted
# [16:16:41] Explicit valence for atom # 1 O, 7, is greater than permitted
# [16:16:41] Explicit valence for atom # 1 O, 13, is greater than permitted
# [16:16:41] Explicit valence for atom # 1 O, 12, is greater than permitted
# [16:16:41] Explicit valence for atom # 1 N, 17, is greater than permitted
# [16:16:41] Explicit valence for atom # 1 C, 8, is greater than permitted
# [16:16:41] Explicit valence for atom # 1 F, 7, is greater than permitted
# [16:16:41] Explicit valence for atom # 1 Br, 14, is greater than permitted
# [16:16:41] Explicit valence for atom # 1 O, 8, is greater than permitted
# [16:16:41] Explicit valence for atom # 1 H, 7, is greater than permitted
# [16:16:41] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:16:42] Explicit valence for atom # 1 O, 3, is greater than permitted
# [16:16:42] Explicit valence for atom # 1 F, 17, is greater than permitted
# [16:16:42] Explicit valence for atom # 1 C, 8, is greater than permitted
# [16:16:42] Explicit valence for atom # 1 O, 4, is greater than permitted
# [16:16:42] Explicit valence for atom # 1 O, 14, is greater than permitted
# [16:16:42] Explicit valence for atom # 1 O, 6, is greater than permitted
# [16:16:42] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:16:42] Explicit valence for atom # 1 F, 11, is greater than permitted
# [16:16:42] Explicit valence for atom # 1 C, 8, is greater than permitted
# [16:16:42] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:16:42] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:16:43] Explicit valence for atom # 4 F, 13, is greater than permitted
# [16:16:43] Explicit valence for atom # 1 B, 14, is greater than permitted
# [16:16:43] Explicit valence for atom # 1 F, 4, is greater than permitted
# [16:16:43] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:16:43] Explicit valence for atom # 1 C, 15, is greater than permitted
# [16:16:43] Explicit valence for atom # 1 O, 15, is greater than permitted
# [16:16:43] Explicit valence for atom # 1 C, 7, is greater than permitted
# [16:16:43] Explicit valence for atom # 1 C, 17, is greater than permitted
# [16:16:43] Explicit valence for atom # 3 Cl, 3, is greater than permitted
# [16:16:44] Explicit valence for atom # 1 As, 19, is greater than permitted
# [16:16:44] Explicit valence for atom # 1 O, 9, is greater than permitted
# [16:16:44] Explicit valence for atom # 1 O, 7, is greater than permitted
# [16:16:44] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:16:44] Explicit valence for atom # 1 O, 10, is greater than permitted
# [16:16:44] Explicit valence for atom # 1 O, 6, is greater than permitted
# [16:16:44] Explicit valence for atom # 1 C, 17, is greater than permitted
# [16:16:44] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:16:45] Explicit valence for atom # 1 C, 5, is greater than permitted
# [16:16:45] Explicit valence for atom # 1 C, 11, is greater than permitted
# [16:16:45] Explicit valence for atom # 1 S, 11, is greater than permitted
# [16:16:45] Explicit valence for atom # 1 C, 11, is greater than permitted
# [16:16:45] Explicit valence for atom # 1 C, 11, is greater than permitted
# [16:16:45] Explicit valence for atom # 1 C, 8, is greater than permitted
# [16:16:45] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:16:45] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:16:45] Explicit valence for atom # 1 C, 15, is greater than permitted
# [16:16:46] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:16:46] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:16:46] Explicit valence for atom # 1 Cl, 11, is greater than permitted
# [16:16:46] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:16:46] Explicit valence for atom # 0 F, 7, is greater than permitted
# [16:16:46] Explicit valence for atom # 0 Si, 7, is greater than permitted
# [16:16:46] Explicit valence for atom # 1 C, 10, is greater than permitted
# [16:16:46] Explicit valence for atom # 1 C, 15, is greater than permitted
# [16:16:46] Explicit valence for atom # 1 Br, 11, is greater than permitted
# [16:16:46] Explicit valence for atom # 1 Cl, 6, is greater than permitted
# [16:16:47] Explicit valence for atom # 1 C, 15, is greater than permitted
# [16:16:47] Explicit valence for atom # 0 F, 11, is greater than permitted
# [16:16:47] Explicit valence for atom # 1 O, 13, is greater than permitted
# [16:16:47] Explicit valence for atom # 1 C, 11, is greater than permitted
# [16:16:47] Explicit valence for atom # 0 F, 8, is greater than permitted
# [16:16:47] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:16:48] Explicit valence for atom # 1 C, 15, is greater than permitted
# [16:16:48] Explicit valence for atom # 1 O, 16, is greater than permitted
# [16:16:48] Explicit valence for atom # 1 F, 10, is greater than permitted
# [16:16:48] Explicit valence for atom # 1 C, 11, is greater than permitted
# Valid molecule SMILES: CC(C)(C)[AsH2]
# Took 90 tries
# [16:16:48] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:16:49] Explicit valence for atom # 1 N, 10, is greater than permitted
# [16:16:49] Explicit valence for atom # 1 N, 14, is greater than permitted
# [16:16:49] Explicit valence for atom # 1 O, 5, is greater than permitted
# [16:16:49] Explicit valence for atom # 1 O, 4, is greater than permitted
# [16:16:50] Explicit valence for atom # 1 O, 8, is greater than permitted
# [16:16:50] Explicit valence for atom # 1 C, 17, is greater than permitted
# [16:16:50] Explicit valence for atom # 1 N, 9, is greater than permitted
# [16:16:51] Explicit valence for atom # 1 O, 12, is greater than permitted
# [16:16:51] Explicit valence for atom # 6 Br, 6, is greater than permitted
# [16:16:51] Explicit valence for atom # 1 C, 7, is greater than permitted
# [16:16:51] Explicit valence for atom # 1 C, 19, is greater than permitted
# [16:16:51] Explicit valence for atom # 1 Cl, 9, is greater than permitted
# [16:16:51] Explicit valence for atom # 0 I, 9, is greater than permitted
# [16:16:51] Explicit valence for atom # 1 C, 11, is greater than permitted
# [16:16:51] Explicit valence for atom # 1 C, 6, is greater than permitted
# [16:16:51] Explicit valence for atom # 0 C, 5, is greater than permitted
# [16:16:51] Explicit valence for atom # 8 I, 11, is greater than permitted
# [16:16:51] Explicit valence for atom # 1 C, 5, is greater than permitted
# [16:16:51] Explicit valence for atom # 1 I, 8, is greater than permitted
# [16:16:52] Explicit valence for atom # 1 Br, 13, is greater than permitted
# [16:16:52] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:16:52] Explicit valence for atom # 1 O, 3, is greater than permitted
# [16:16:52] Explicit valence for atom # 1 S, 19, is greater than permitted
# [16:16:52] Explicit valence for atom # 1 C, 17, is greater than permitted
# [16:16:52] Explicit valence for atom # 1 N, 8, is greater than permitted
# [16:16:52] Explicit valence for atom # 1 O, 3, is greater than permitted
# [16:16:52] Explicit valence for atom # 1 C, 8, is greater than permitted
# [16:16:52] Explicit valence for atom # 1 Cl, 10, is greater than permitted
# [16:16:53] Explicit valence for atom # 1 O, 7, is greater than permitted
# [16:16:53] Explicit valence for atom # 1 O, 5, is greater than permitted
# [16:16:53] Explicit valence for atom # 1 Cl, 4, is greater than permitted
# [16:16:53] Explicit valence for atom # 1 C, 13, is greater than permitted
# [16:16:53] Explicit valence for atom # 0 Cl, 12, is greater than permitted
# [16:16:53] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# [16:16:53] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:16:53] Explicit valence for atom # 1 N, 8, is greater than permitted
# [16:16:53] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:16:53] Explicit valence for atom # 1 Al, 10, is greater than permitted
# [16:16:53] Explicit valence for atom # 1 O, 18, is greater than permitted
# [16:16:53] Explicit valence for atom # 1 N, 12, is greater than permitted
# [16:16:53] Explicit valence for atom # 1 Cl, 17, is greater than permitted
# [16:16:53] Explicit valence for atom # 1 Si, 12, is greater than permitted
# [16:16:53] Explicit valence for atom # 1 H, 4, is greater than permitted
# [16:16:53] Explicit valence for atom # 1 O, 8, is greater than permitted
# [16:16:54] Explicit valence for atom # 1 O, 10, is greater than permitted
# [16:16:54] Explicit valence for atom # 1 C, 13, is greater than permitted
# [16:16:54] Explicit valence for atom # 1 C, 7, is greater than permitted
# [16:16:54] Explicit valence for atom # 1 C, 11, is greater than permitted
# [16:16:54] Explicit valence for atom # 1 P, 12, is greater than permitted
# [16:16:54] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:16:54] Explicit valence for atom # 1 H, 10, is greater than permitted
# [16:16:54] Explicit valence for atom # 1 O, 8, is greater than permitted
# [16:16:54] Explicit valence for atom # 1 O, 10, is greater than permitted
# [16:16:54] Explicit valence for atom # 1 O, 16, is greater than permitted
# [16:16:54] Explicit valence for atom # 1 N, 12, is greater than permitted
# [16:16:54] Explicit valence for atom # 1 C, 13, is greater than permitted
# [16:16:55] WARNING: not removing hydrogen atom without neighbors
# [16:16:55] Explicit valence for atom # 1 Cl, 12, is greater than permitted
# [16:16:55] Explicit valence for atom # 1 O, 7, is greater than permitted
# [16:16:55] Explicit valence for atom # 0 As, 10, is greater than permitted
# [16:16:55] Explicit valence for atom # 1 O, 7, is greater than permitted
# [16:16:55] Explicit valence for atom # 1 O, 17, is greater than permitted
# [16:16:55] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:16:55] Explicit valence for atom # 1 S, 18, is greater than permitted
# [16:16:55] Explicit valence for atom # 1 O, 7, is greater than permitted
# [16:16:55] Explicit valence for atom # 1 O, 6, is greater than permitted
# [16:16:55] Explicit valence for atom # 1 O, 13, is greater than permitted
# [16:16:55] Explicit valence for atom # 1 C, 11, is greater than permitted
# [16:16:56] Explicit valence for atom # 1 O, 4, is greater than permitted
# [16:16:56] Explicit valence for atom # 1 C, 13, is greater than permitted
# [16:16:56] Explicit valence for atom # 1 O, 8, is greater than permitted
# [16:16:56] Explicit valence for atom # 1 I, 9, is greater than permitted
# [16:16:56] Explicit valence for atom # 1 O, 13, is greater than permitted
# [16:16:56] Explicit valence for atom # 1 O, 8, is greater than permitted
# [16:16:56] Explicit valence for atom # 1 C, 17, is greater than permitted
# [16:16:56] Explicit valence for atom # 1 O, 16, is greater than permitted
# [16:16:56] Explicit valence for atom # 1 C, 7, is greater than permitted
# [16:16:57] Explicit valence for atom # 1 N, 4, is greater than permitted
# [16:16:57] Explicit valence for atom # 1 N, 10, is greater than permitted
# [16:16:57] Explicit valence for atom # 1 C, 11, is greater than permitted
# [16:16:57] Explicit valence for atom # 1 C, 17, is greater than permitted
# [16:16:57] Explicit valence for atom # 1 O, 11, is greater than permitted
# [16:16:57] Explicit valence for atom # 1 C, 15, is greater than permitted
# [16:16:57] Explicit valence for atom # 1 S, 19, is greater than permitted
# [16:16:58] Explicit valence for atom # 1 Cl, 16, is greater than permitted
# [16:16:58] Explicit valence for atom # 1 F, 12, is greater than permitted
# [16:16:58] Explicit valence for atom # 1 O, 15, is greater than permitted
# [16:16:58] Explicit valence for atom # 1 Al, 11, is greater than permitted
# [16:16:58] Explicit valence for atom # 1 O, 7, is greater than permitted
# [16:16:58] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:16:58] Explicit valence for atom # 1 C, 18, is greater than permitted
# [16:16:58] Explicit valence for atom # 1 Bi, 9, is greater than permitted
# [16:16:58] Explicit valence for atom # 1 C, 17, is greater than permitted
# [16:16:58] Explicit valence for atom # 0 F, 9, is greater than permitted
# [16:16:58] Explicit valence for atom # 1 N, 15, is greater than permitted
# [16:16:58] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:16:59] Explicit valence for atom # 1 O, 3, is greater than permitted
# [16:16:59] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:16:59] Explicit valence for atom # 1 C, 13, is greater than permitted
# [16:16:59] Explicit valence for atom # 1 C, 15, is greater than permitted
# [16:16:59] Explicit valence for atom # 1 C, 8, is greater than permitted
# [16:16:59] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:17:00] Explicit valence for atom # 1 O, 8, is greater than permitted
# [16:17:00] Explicit valence for atom # 1 O, 5, is greater than permitted
# [16:17:00] Explicit valence for atom # 3 C, 7, is greater than permitted
# [16:17:00] Explicit valence for atom # 1 N, 4, is greater than permitted
# [16:17:00] Explicit valence for atom # 1 Cl, 7, is greater than permitted
# [16:17:00] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# [16:17:00] Explicit valence for atom # 1 C, 17, is greater than permitted
# [16:17:00] Explicit valence for atom # 2 O, 13, is greater than permitted
# [16:17:00] Explicit valence for atom # 1 F, 11, is greater than permitted
# [16:17:00] Explicit valence for atom # 1 O, 15, is greater than permitted
# [16:17:00] Explicit valence for atom # 1 O, 11, is greater than permitted
# [16:17:00] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:17:00] Explicit valence for atom # 1 C, 11, is greater than permitted
# [16:17:01] Explicit valence for atom # 1 H, 2, is greater than permitted
# [16:17:01] Explicit valence for atom # 1 O, 3, is greater than permitted
# [16:17:01] Explicit valence for atom # 1 O, 4, is greater than permitted
# [16:17:01] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:17:01] Explicit valence for atom # 1 O, 18, is greater than permitted
# [16:17:01] Explicit valence for atom # 1 C, 5, is greater than permitted
# [16:17:01] Explicit valence for atom # 1 O, 8, is greater than permitted
# [16:17:01] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:17:01] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:17:01] Explicit valence for atom # 1 O, 7, is greater than permitted
# [16:17:01] Explicit valence for atom # 1 C, 15, is greater than permitted
# [16:17:01] Explicit valence for atom # 1 Br, 18, is greater than permitted
# [16:17:01] Explicit valence for atom # 2 H, 4, is greater than permitted
# [16:17:01] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:17:02] Explicit valence for atom # 1 Cl, 10, is greater than permitted
# [16:17:02] Explicit valence for atom # 1 C, 6, is greater than permitted
# [16:17:02] Explicit valence for atom # 2 O, 5, is greater than permitted
# [16:17:02] Explicit valence for atom # 1 C, 8, is greater than permitted
# [16:17:02] Explicit valence for atom # 2 Bi, 9, is greater than permitted
# [16:17:02] Explicit valence for atom # 1 O, 4, is greater than permitted
# [16:17:02] Explicit valence for atom # 1 O, 8, is greater than permitted
# [16:17:02] Explicit valence for atom # 1 C, 5, is greater than permitted
# [16:17:02] Explicit valence for atom # 1 C, 13, is greater than permitted
# [16:17:03] Explicit valence for atom # 1 O, 4, is greater than permitted
# [16:17:03] Explicit valence for atom # 1 B, 5, is greater than permitted
# [16:17:03] Explicit valence for atom # 1 C, 10, is greater than permitted
# [16:17:03] Explicit valence for atom # 0 S, 13, is greater than permitted
# [16:17:03] Explicit valence for atom # 1 O, 8, is greater than permitted
# [16:17:04] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:17:04] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:17:04] Explicit valence for atom # 1 C, 10, is greater than permitted
# [16:17:04] Explicit valence for atom # 1 F, 9, is greater than permitted
# [16:17:04] Explicit valence for atom # 1 F, 5, is greater than permitted
# [16:17:05] Explicit valence for atom # 1 C, 7, is greater than permitted
# [16:17:05] Explicit valence for atom # 1 O, 6, is greater than permitted
# [16:17:05] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:17:05] Explicit valence for atom # 1 Br, 19, is greater than permitted
# [16:17:05] Explicit valence for atom # 1 O, 9, is greater than permitted
# [16:17:06] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:17:06] Explicit valence for atom # 1 I, 16, is greater than permitted
# [16:17:06] Explicit valence for atom # 0 Br, 11, is greater than permitted
# [16:17:06] Explicit valence for atom # 1 S, 16, is greater than permitted
# [16:17:06] Explicit valence for atom # 1 H, 2, is greater than permitted
# [16:17:06] Explicit valence for atom # 1 O, 11, is greater than permitted
# Valid molecule SMILES: CC1C23CC12C3
# Took 163 tries
# [16:17:07] Explicit valence for atom # 1 O, 5, is greater than permitted
# [16:17:07] Explicit valence for atom # 1 C, 6, is greater than permitted
# [16:17:07] Explicit valence for atom # 0 S, 13, is greater than permitted
# [16:17:07] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:17:07] Explicit valence for atom # 1 N, 15, is greater than permitted
# [16:17:07] Explicit valence for atom # 1 O, 10, is greater than permitted
# [16:17:07] Explicit valence for atom # 0 F, 6, is greater than permitted
# [16:17:08] Explicit valence for atom # 1 N, 11, is greater than permitted
# [16:17:08] Explicit valence for atom # 1 Bi, 8, is greater than permitted
# [16:17:08] Explicit valence for atom # 1 O, 5, is greater than permitted
# [16:17:08] Explicit valence for atom # 1 O, 5, is greater than permitted
# [16:17:08] WARNING: not removing hydrogen atom without neighbors
# [16:17:08] Explicit valence for atom # 1 Br, 13, is greater than permitted
# [16:17:08] Explicit valence for atom # 1 C, 5, is greater than permitted
# [16:17:09] Explicit valence for atom # 1 C, 8, is greater than permitted
# [16:17:09] Explicit valence for atom # 2 F, 4, is greater than permitted
# [16:17:09] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:17:09] Explicit valence for atom # 1 O, 12, is greater than permitted
# [16:17:09] Explicit valence for atom # 1 O, 5, is greater than permitted
# Valid molecule SMILES: [AlH2]P
# Took 19 tries
# [16:17:10] Explicit valence for atom # 1 O, 8, is greater than permitted
# [16:17:10] Explicit valence for atom # 0 Br, 12, is greater than permitted
# [16:17:10] Explicit valence for atom # 1 C, 10, is greater than permitted
# [16:17:10] Explicit valence for atom # 1 O, 10, is greater than permitted
# [16:17:10] Explicit valence for atom # 1 Al, 13, is greater than permitted
# [16:17:10] Explicit valence for atom # 1 F, 9, is greater than permitted
# [16:17:10] Explicit valence for atom # 1 I, 16, is greater than permitted
# [16:17:11] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:17:11] Explicit valence for atom # 8 F, 2, is greater than permitted
# [16:17:11] Explicit valence for atom # 1 O, 7, is greater than permitted
# [16:17:11] Explicit valence for atom # 1 C, 15, is greater than permitted
# [16:17:11] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:17:11] Explicit valence for atom # 1 H, 2, is greater than permitted
# [16:17:11] Explicit valence for atom # 1 Cl, 13, is greater than permitted
# [16:17:11] Explicit valence for atom # 1 O, 14, is greater than permitted
# [16:17:12] Explicit valence for atom # 1 C, 11, is greater than permitted
# [16:17:12] Explicit valence for atom # 1 O, 16, is greater than permitted
# [16:17:12] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:17:12] Explicit valence for atom # 1 O, 5, is greater than permitted
# [16:17:13] Explicit valence for atom # 1 C, 10, is greater than permitted
# [16:17:13] Explicit valence for atom # 1 F, 2, is greater than permitted
# [16:17:13] Explicit valence for atom # 1 O, 8, is greater than permitted
# [16:17:13] Explicit valence for atom # 1 C, 5, is greater than permitted
# [16:17:13] Explicit valence for atom # 1 P, 14, is greater than permitted
# [16:17:13] Explicit valence for atom # 1 Cl, 5, is greater than permitted
# [16:17:13] Explicit valence for atom # 1 C, 15, is greater than permitted
# [16:17:14] Explicit valence for atom # 1 N, 9, is greater than permitted
# [16:17:14] Explicit valence for atom # 4 O, 7, is greater than permitted
# [16:17:14] Explicit valence for atom # 1 O, 19, is greater than permitted
# [16:17:14] Explicit valence for atom # 1 I, 16, is greater than permitted
# [16:17:14] Explicit valence for atom # 1 C, 8, is greater than permitted
# [16:17:14] Explicit valence for atom # 1 Si, 17, is greater than permitted
# [16:17:14] Explicit valence for atom # 1 I, 15, is greater than permitted
# [16:17:14] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:17:14] Explicit valence for atom # 2 I, 15, is greater than permitted
# [16:17:15] Explicit valence for atom # 1 O, 17, is greater than permitted
# [16:17:15] Explicit valence for atom # 1 C, 16, is greater than permitted
# Valid molecule SMILES: [AlH3]
# Took 38 tries
# [16:17:15] Explicit valence for atom # 1 C, 10, is greater than permitted
# [16:17:15] Explicit valence for atom # 1 O, 11, is greater than permitted
# [16:17:15] Explicit valence for atom # 1 C, 13, is greater than permitted
# [16:17:15] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:17:15] Explicit valence for atom # 1 C, 6, is greater than permitted
# [16:17:15] Explicit valence for atom # 1 F, 3, is greater than permitted
# [16:17:16] Explicit valence for atom # 1 C, 10, is greater than permitted
# [16:17:16] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:17:16] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# [16:17:16] Explicit valence for atom # 1 O, 5, is greater than permitted
# [16:17:16] Explicit valence for atom # 1 O, 12, is greater than permitted
# [16:17:16] Explicit valence for atom # 1 C, 13, is greater than permitted
# [16:17:16] Explicit valence for atom # 1 O, 8, is greater than permitted
# [16:17:16] Explicit valence for atom # 1 O, 12, is greater than permitted
# [16:17:16] Explicit valence for atom # 1 O, 7, is greater than permitted
# [16:17:16] Explicit valence for atom # 1 S, 17, is greater than permitted
# [16:17:17] Explicit valence for atom # 1 H, 3, is greater than permitted
# [16:17:17] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:17:17] Explicit valence for atom # 1 O, 11, is greater than permitted
# [16:17:17] Explicit valence for atom # 1 C, 18, is greater than permitted
# [16:17:18] Explicit valence for atom # 1 F, 7, is greater than permitted
# [16:17:18] Explicit valence for atom # 1 C, 10, is greater than permitted
# [16:17:18] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:17:18] Explicit valence for atom # 1 O, 4, is greater than permitted
# [16:17:18] Explicit valence for atom # 1 O, 5, is greater than permitted
# [16:17:18] Explicit valence for atom # 1 O, 4, is greater than permitted
# [16:17:18] Explicit valence for atom # 1 C, 15, is greater than permitted
# [16:17:18] Explicit valence for atom # 1 O, 4, is greater than permitted
# [16:17:18] Explicit valence for atom # 1 O, 10, is greater than permitted
# [16:17:18] Explicit valence for atom # 1 O, 15, is greater than permitted
# [16:17:18] Explicit valence for atom # 1 B, 12, is greater than permitted
# [16:17:19] Explicit valence for atom # 1 O, 14, is greater than permitted
# [16:17:19] Explicit valence for atom # 1 C, 12, is greater than permitted
# Valid molecule SMILES: C12C3C1C23
# Took 34 tries
# [16:17:19] Explicit valence for atom # 1 C, 11, is greater than permitted
# [16:17:19] Explicit valence for atom # 1 Si, 8, is greater than permitted
# [16:17:19] Explicit valence for atom # 1 Sn, 15, is greater than permitted
# [16:17:19] Explicit valence for atom # 1 O, 10, is greater than permitted
# [16:17:19] Explicit valence for atom # 1 O, 8, is greater than permitted
# [16:17:19] Explicit valence for atom # 1 Br, 17, is greater than permitted
# [16:17:19] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:17:20] Explicit valence for atom # 1 C, 7, is greater than permitted
# [16:17:20] Explicit valence for atom # 1 O, 9, is greater than permitted
# [16:17:20] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:17:20] Explicit valence for atom # 2 N, 4, is greater than permitted
# [16:17:20] Explicit valence for atom # 1 O, 5, is greater than permitted
# [16:17:20] Explicit valence for atom # 1 N, 12, is greater than permitted
# [16:17:20] Explicit valence for atom # 1 O, 5, is greater than permitted
# [16:17:21] Explicit valence for atom # 1 O, 13, is greater than permitted
# [16:17:21] Explicit valence for atom # 1 C, 17, is greater than permitted
# [16:17:21] Explicit valence for atom # 1 C, 11, is greater than permitted
# [16:17:21] Explicit valence for atom # 1 C, 7, is greater than permitted
# [16:17:21] Explicit valence for atom # 1 O, 8, is greater than permitted
# [16:17:21] Explicit valence for atom # 1 N, 18, is greater than permitted
# [16:17:22] Explicit valence for atom # 1 C, 10, is greater than permitted
# [16:17:22] Explicit valence for atom # 1 O, 3, is greater than permitted
# [16:17:22] Explicit valence for atom # 0 P, 11, is greater than permitted
# [16:17:22] Explicit valence for atom # 1 O, 12, is greater than permitted
# [16:17:22] Explicit valence for atom # 1 H, 2, is greater than permitted
# [16:17:23] Explicit valence for atom # 1 C, 8, is greater than permitted
# [16:17:23] Explicit valence for atom # 1 C, 13, is greater than permitted
# [16:17:23] Explicit valence for atom # 1 C, 15, is greater than permitted
# [16:17:23] Explicit valence for atom # 1 C, 13, is greater than permitted
# [16:17:24] Explicit valence for atom # 1 O, 13, is greater than permitted
# [16:17:24] Explicit valence for atom # 1 O, 8, is greater than permitted
# [16:17:24] Explicit valence for atom # 1 O, 11, is greater than permitted
# ...
# [16:24:30] Explicit valence for atom # 1 O, 16, is greater than permitted
# [16:24:30] Explicit valence for atom # 1 C, 13, is greater than permitted
# [16:24:30] Explicit valence for atom # 1 S, 18, is greater than permitted
# [16:24:30] Explicit valence for atom # 1 Br, 15, is greater than permitted
# [16:24:30] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:24:30] Explicit valence for atom # 1 Si, 16, is greater than permitted
# [16:24:30] Explicit valence for atom # 1 C, 11, is greater than permitted
# [16:24:31] Explicit valence for atom # 1 O, 16, is greater than permitted
# [16:24:31] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:24:31] Explicit valence for atom # 1 C, 13, is greater than permitted
# [16:24:31] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:24:31] Explicit valence for atom # 1 C, 13, is greater than permitted
# [16:24:31] Explicit valence for atom # 1 C, 10, is greater than permitted
# [16:24:32] Explicit valence for atom # 1 O, 17, is greater than permitted
# [16:24:32] Explicit valence for atom # 1 S, 13, is greater than permitted
# [16:24:32] Explicit valence for atom # 1 C, 11, is greater than permitted
# [16:24:32] Explicit valence for atom # 0 F, 2, is greater than permitted
# [16:24:32] Explicit valence for atom # 1 C, 10, is greater than permitted
# Valid molecule SMILES: CC(C)C
# Took 64 tries
# [16:24:32] Explicit valence for atom # 1 C, 13, is greater than permitted
# [16:24:32] Explicit valence for atom # 1 C, 7, is greater than permitted
# [16:24:32] Explicit valence for atom # 2 Br, 2, is greater than permitted
# [16:24:32] Explicit valence for atom # 0 B, 9, is greater than permitted
# [16:24:32] Explicit valence for atom # 1 Cl, 9, is greater than permitted
# [16:24:33] Explicit valence for atom # 1 C, 13, is greater than permitted
# [16:24:33] Explicit valence for atom # 1 F, 8, is greater than permitted
# [16:24:33] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:24:33] Explicit valence for atom # 1 I, 10, is greater than permitted
# [16:24:33] Explicit valence for atom # 2 C, 8, is greater than permitted
# [16:24:33] Explicit valence for atom # 1 As, 16, is greater than permitted
# [16:24:34] Explicit valence for atom # 1 O, 16, is greater than permitted
# [16:24:34] Explicit valence for atom # 1 C, 15, is greater than permitted
# [16:24:34] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:24:34] Explicit valence for atom # 1 B, 10, is greater than permitted
# [16:24:34] Explicit valence for atom # 1 O, 13, is greater than permitted
# [16:24:34] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:24:34] Explicit valence for atom # 1 N, 7, is greater than permitted
# [16:24:35] Explicit valence for atom # 1 C, 11, is greater than permitted
# [16:24:35] Explicit valence for atom # 1 O, 13, is greater than permitted
# [16:24:35] Explicit valence for atom # 1 C, 10, is greater than permitted
# [16:24:35] Explicit valence for atom # 1 C, 13, is greater than permitted
# [16:24:35] Explicit valence for atom # 1 O, 6, is greater than permitted
# [16:24:35] Explicit valence for atom # 1 H, 15, is greater than permitted
# [16:24:35] Explicit valence for atom # 1 O, 8, is greater than permitted
# [16:24:36] WARNING: not removing hydrogen atom without neighbors
# [16:24:36] Explicit valence for atom # 0 I, 9, is greater than permitted
# [16:24:36] Explicit valence for atom # 1 O, 10, is greater than permitted
# [16:24:36] Explicit valence for atom # 1 N, 14, is greater than permitted
# [16:24:36] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:24:36] Explicit valence for atom # 1 O, 6, is greater than permitted
# [16:24:36] Explicit valence for atom # 1 O, 17, is greater than permitted
# [16:24:37] Explicit valence for atom # 1 N, 13, is greater than permitted
# [16:24:37] Explicit valence for atom # 0 As, 8, is greater than permitted
# [16:24:37] Explicit valence for atom # 1 O, 4, is greater than permitted
# [16:24:37] Explicit valence for atom # 5 Br, 2, is greater than permitted
# [16:24:37] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:24:37] Explicit valence for atom # 1 O, 10, is greater than permitted
# [16:24:37] Explicit valence for atom # 1 F, 7, is greater than permitted
# [16:24:37] Explicit valence for atom # 1 O, 11, is greater than permitted
# [16:24:38] Explicit valence for atom # 0 O, 6, is greater than permitted
# [16:24:38] Explicit valence for atom # 1 H, 11, is greater than permitted
# [16:24:38] Explicit valence for atom # 1 O, 15, is greater than permitted
# [16:24:38] Explicit valence for atom # 1 F, 4, is greater than permitted
# [16:24:38] Explicit valence for atom # 2 C, 12, is greater than permitted
# [16:24:38] Explicit valence for atom # 1 O, 6, is greater than permitted
# [16:24:39] Explicit valence for atom # 1 O, 10, is greater than permitted
# [16:24:39] Explicit valence for atom # 1 C, 10, is greater than permitted
# [16:24:39] Explicit valence for atom # 1 C, 13, is greater than permitted
# [16:24:39] Explicit valence for atom # 0 Sn, 9, is greater than permitted
# [16:24:39] Explicit valence for atom # 1 C, 8, is greater than permitted
# [16:24:39] Explicit valence for atom # 1 C, 17, is greater than permitted
# [16:24:39] Explicit valence for atom # 1 O, 11, is greater than permitted
# [16:24:40] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:24:40] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:24:40] Explicit valence for atom # 1 C, 8, is greater than permitted
# [16:24:40] Explicit valence for atom # 1 O, 13, is greater than permitted
# [16:24:40] Explicit valence for atom # 1 O, 3, is greater than permitted
# [16:24:40] Explicit valence for atom # 1 O, 8, is greater than permitted
# [16:24:40] Explicit valence for atom # 1 O, 19, is greater than permitted
# [16:24:40] Explicit valence for atom # 0 F, 4, is greater than permitted
# [16:24:40] Explicit valence for atom # 1 H, 15, is greater than permitted
# [16:24:41] Explicit valence for atom # 1 O, 13, is greater than permitted
# [16:24:41] Explicit valence for atom # 1 O, 3, is greater than permitted
# [16:24:41] Explicit valence for atom # 1 Br, 12, is greater than permitted
# [16:24:41] Explicit valence for atom # 2 C, 11, is greater than permitted
# [16:24:41] Explicit valence for atom # 1 C, 6, is greater than permitted
# [16:24:41] Explicit valence for atom # 2 F, 3, is greater than permitted
# [16:24:41] Explicit valence for atom # 1 C, 18, is greater than permitted
# [16:24:41] Explicit valence for atom # 1 N, 17, is greater than permitted
# [16:24:42] Explicit valence for atom # 1 O, 5, is greater than permitted
# [16:24:42] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:24:42] Explicit valence for atom # 1 C, 11, is greater than permitted
# [16:24:42] Explicit valence for atom # 1 Cl, 12, is greater than permitted
# [16:24:42] Explicit valence for atom # 1 O, 14, is greater than permitted
# [16:24:42] Explicit valence for atom # 0 I, 10, is greater than permitted
# [16:24:42] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:24:42] Explicit valence for atom # 1 As, 10, is greater than permitted
# [16:24:42] Explicit valence for atom # 1 O, 13, is greater than permitted
# [16:24:42] Explicit valence for atom # 1 F, 3, is greater than permitted
# [16:24:43] Explicit valence for atom # 1 H, 5, is greater than permitted
# [16:24:43] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:24:43] Explicit valence for atom # 1 O, 9, is greater than permitted
# [16:24:43] Explicit valence for atom # 1 F, 6, is greater than permitted
# [16:24:43] Explicit valence for atom # 1 C, 17, is greater than permitted
# [16:24:43] Explicit valence for atom # 1 Cl, 3, is greater than permitted
# [16:24:43] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:24:43] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:24:44] Explicit valence for atom # 1 N, 11, is greater than permitted
# [16:24:44] Explicit valence for atom # 1 O, 5, is greater than permitted
# [16:24:44] Explicit valence for atom # 1 O, 4, is greater than permitted
# Valid molecule SMILES: NN[SnH]
# Took 94 tries
# [16:24:44] Explicit valence for atom # 1 O, 5, is greater than permitted
# [16:24:44] Explicit valence for atom # 1 O, 8, is greater than permitted
# [16:24:44] Explicit valence for atom # 1 P, 16, is greater than permitted
# [16:24:44] Explicit valence for atom # 1 C, 15, is greater than permitted
# [16:24:44] Explicit valence for atom # 1 C, 17, is greater than permitted
# [16:24:45] Explicit valence for atom # 1 F, 12, is greater than permitted
# [16:24:45] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:24:45] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:24:45] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:24:45] Explicit valence for atom # 1 Cl, 10, is greater than permitted
# [16:24:45] Explicit valence for atom # 1 C, 13, is greater than permitted
# [16:24:45] Explicit valence for atom # 1 N, 5, is greater than permitted
# [16:24:45] Explicit valence for atom # 1 Si, 17, is greater than permitted
# [16:24:45] Explicit valence for atom # 1 As, 18, is greater than permitted
# [16:24:46] Explicit valence for atom # 1 C, 10, is greater than permitted
# [16:24:46] Explicit valence for atom # 0 N, 10, is greater than permitted
# [16:24:46] Explicit valence for atom # 2 O, 10, is greater than permitted
# [16:24:46] Explicit valence for atom # 1 O, 7, is greater than permitted
# [16:24:46] Explicit valence for atom # 1 O, 15, is greater than permitted
# [16:24:46] Explicit valence for atom # 1 S, 16, is greater than permitted
# Valid molecule SMILES: [BiH3]
# Took 21 tries
# [16:24:46] Explicit valence for atom # 1 C, 13, is greater than permitted
# [16:24:47] Explicit valence for atom # 1 N, 13, is greater than permitted
# [16:24:47] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:24:47] Explicit valence for atom # 3 C, 5, is greater than permitted
# [16:24:47] Explicit valence for atom # 1 Sn, 7, is greater than permitted
# [16:24:47] Explicit valence for atom # 1 O, 7, is greater than permitted
# [16:24:47] Explicit valence for atom # 1 C, 8, is greater than permitted
# [16:24:47] Explicit valence for atom # 1 C, 8, is greater than permitted
# [16:24:47] Explicit valence for atom # 1 F, 5, is greater than permitted
# [16:24:48] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# [16:24:48] Explicit valence for atom # 1 C, 13, is greater than permitted
# [16:24:48] Explicit valence for atom # 1 O, 5, is greater than permitted
# [16:24:48] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:24:48] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:24:48] Explicit valence for atom # 1 F, 11, is greater than permitted
# [16:24:48] Explicit valence for atom # 1 Cl, 10, is greater than permitted
# [16:24:48] Explicit valence for atom # 1 C, 10, is greater than permitted
# [16:24:48] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:24:48] Explicit valence for atom # 1 O, 13, is greater than permitted
# [16:24:48] Explicit valence for atom # 1 O, 7, is greater than permitted
# [16:24:49] Explicit valence for atom # 7 Cl, 3, is greater than permitted
# [16:24:49] Explicit valence for atom # 1 O, 6, is greater than permitted
# [16:24:49] Explicit valence for atom # 1 O, 3, is greater than permitted
# [16:24:49] Explicit valence for atom # 1 P, 12, is greater than permitted
# [16:24:49] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:24:49] Explicit valence for atom # 1 C, 13, is greater than permitted
# [16:24:49] Explicit valence for atom # 1 O, 16, is greater than permitted
# [16:24:49] Explicit valence for atom # 1 O, 10, is greater than permitted
# [16:24:50] Explicit valence for atom # 1 F, 3, is greater than permitted
# [16:24:50] Explicit valence for atom # 1 Cl, 7, is greater than permitted
# [16:24:50] Explicit valence for atom # 1 Si, 12, is greater than permitted
# [16:24:50] Explicit valence for atom # 1 O, 6, is greater than permitted
# [16:24:50] Explicit valence for atom # 1 N, 7, is greater than permitted
# [16:24:50] Explicit valence for atom # 1 O, 4, is greater than permitted
# [16:24:50] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:24:50] Explicit valence for atom # 1 C, 11, is greater than permitted
# [16:24:51] Explicit valence for atom # 1 O, 16, is greater than permitted
# [16:24:51] Explicit valence for atom # 1 N, 18, is greater than permitted
# [16:24:51] Explicit valence for atom # 1 Si, 9, is greater than permitted
# [16:24:51] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:24:51] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:24:51] Explicit valence for atom # 1 O, 5, is greater than permitted
# [16:24:52] Explicit valence for atom # 1 O, 9, is greater than permitted
# [16:24:52] Explicit valence for atom # 1 N, 6, is greater than permitted
# [16:24:52] Explicit valence for atom # 1 C, 15, is greater than permitted
# [16:24:52] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# [16:24:52] Explicit valence for atom # 1 C, 13, is greater than permitted
# [16:24:52] Explicit valence for atom # 1 N, 4, is greater than permitted
# [16:24:53] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:24:53] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:24:53] Explicit valence for atom # 2 O, 3, is greater than permitted
# [16:24:53] Explicit valence for atom # 2 O, 3, is greater than permitted
# [16:24:54] Explicit valence for atom # 1 F, 4, is greater than permitted
# [16:24:54] Explicit valence for atom # 1 Cl, 3, is greater than permitted
# [16:24:54] Explicit valence for atom # 1 C, 6, is greater than permitted
# [16:24:54] Explicit valence for atom # 1 C, 6, is greater than permitted
# [16:24:54] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:24:54] Explicit valence for atom # 1 O, 10, is greater than permitted
# [16:24:55] Explicit valence for atom # 1 O, 3, is greater than permitted
# [16:24:55] Explicit valence for atom # 0 S, 12, is greater than permitted
# [16:24:55] Explicit valence for atom # 1 O, 12, is greater than permitted
# [16:24:55] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:24:55] Explicit valence for atom # 1 C, 9, is greater than permitted
# [16:24:55] Explicit valence for atom # 0 C, 8, is greater than permitted
# [16:24:56] Explicit valence for atom # 1 O, 7, is greater than permitted
# [16:24:56] Explicit valence for atom # 1 O, 14, is greater than permitted
# [16:24:56] Explicit valence for atom # 1 P, 8, is greater than permitted
# Valid molecule SMILES: C1C23CC12C3
# Took 69 tries
# [16:24:57] WARNING: not removing hydrogen atom without neighbors
# [16:24:57] Explicit valence for atom # 1 C, 15, is greater than permitted
# [16:24:57] Explicit valence for atom # 1 O, 13, is greater than permitted
# [16:24:57] Explicit valence for atom # 1 F, 6, is greater than permitted
# [16:24:57] Explicit valence for atom # 1 S, 8, is greater than permitted
# [16:24:58] Explicit valence for atom # 1 O, 4, is greater than permitted
# [16:24:58] Explicit valence for atom # 1 O, 5, is greater than permitted
# [16:24:58] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# [16:24:58] Explicit valence for atom # 1 C, 11, is greater than permitted
# [16:24:58] Explicit valence for atom # 1 O, 10, is greater than permitted
# [16:24:59] Explicit valence for atom # 1 C, 16, is greater than permitted
# [16:24:59] Explicit valence for atom # 1 C, 12, is greater than permitted
# [16:24:59] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:25:00] Explicit valence for atom # 1 C, 18, is greater than permitted
# [16:25:00] Explicit valence for atom # 1 O, 4, is greater than permitted
# Valid molecule SMILES: CC(C)(C)C
# Took 15 tries
# [16:25:01] Explicit valence for atom # 1 C, 14, is greater than permitted
# [16:25:01] Explicit valence for atom # 1 C, 11, is greater than permitted
# Valid molecule SMILES: C1C2C3C1C23
# Took 3 tries

# %%
set_of_new_smiles
# Out:
# {'B[Hg]',
#  'C12C3C1C23',
#  'C12C3C45C1C34C25',
#  'C1C23C4C5C2C14C53',
#  'C1C23CC1(C2)C3',
#  'C1C23CC12C3',
#  'C1C23CC14C2C34',
#  'C1C2C3C1C23',
#  'C1C2CC12',
#  'C1CCC1',
#  'CC(C)(C)C',
#  'CC(C)(C)[AsH2]',
#  'CC(C)C',
#  'CC(C)P',
#  'CC(C)[AsH2]',
#  'CC1(C)CC1',
#  'CC1(C)CCC1',
#  'CC12CC(C1)C2',
#  'CC12CC1C2',
#  'CC1C23CC1(C2)C3',
#  'CC1C23CC12C3',
#  'CC1CC1',
#  'CC1CCC1',
#  'CCC(C)C',
#  'CCCC',
#  'C[Hg]1234567([SnH])([Hg])B[Hg]189%10(C2)C3[Hg]412[Si]85[As]196[AsH]2%107',
#  'C[SiH2]C(C)(C)C',
#  'C[Sn]C',
#  'ClC1[Al]2C[Hg]12Cl',
#  'Cl[Hg]I',
#  'F[Hg]12(F)(Cl)(Cl)(Cl)(Cl)S[Hg]1(S)S2',
#  'F[IH]P',
#  'F[PH](F)(P)(Cl)(Cl)Cl',
#  'I[AlH2]12CP(P1)[Sn]2',
#  'N1C23NC12[AsH]3',
#  'NN(P)[BiH2]',
#  'NN([AsH2])(Br)[SnH]',
#  'NN[BiH2]',
#  'NN[SnH]',
#  'N[SiH2]Br',
#  'O1OOO1',
#  'OO1OO[AlH]1',
#  'O[Al]1O2NO21',
#  'O[SiH3]',
#  'PN[SnH]',
#  'P[BiH][Hg]',
#  '[AlH2]N[SiH3]',
#  '[AlH2]P',
#  '[AlH3]',
#  '[AsH3]',
#  '[BiH3]',
#  '[HH]',
#  '[H]C([H])([H])C',
#  '[H]CC',
#  '[H]P',
#  '[H][Al]([H])[H]',
#  '[H][BiH2]',
#  '[H][Hg]([H])([H])([H])([H])([H])([H])(F)(F)P',
#  '[H][Hg]([H])([H])([H])([H])([H])([H])([H])([H])[SnH]',
#  '[H][Hg]12([H])([H])([H])([H])([H])([H])([H])B3[Hg]1[Hg]32',
#  '[H][Hg]1234([H])([H])([H])([H])(B)([SiH3])[SiH]5[SH]167[SH]2[Hg]563[Bi]74',
#  '[H][PH]([H])([H])([H])([H])SS',
#  '[H][SnH]',
#  '[SiH4]',
#  '[SnH2]'}

# %% [markdown]
# # Next Steps: Add new molecules (X amount) to training data, retrain model, test and report scores. Then, improve our code!

# %%
new_data = pd.DataFrame({"SMILE": list(set_of_new_smiles), "ID": "NA", "Function": 1})

# %%
print(train_df.tail())
#train_df.shape
train_df = pd.concat([train_df, new_data], ignore_index=True)
# Out:
#                                                  SMILE  ID  Function
# 676  B.[HH].[HH].[HH].[HH].[HH].[HH].[HH].[HH].[HH]...  NA         1
# 677             C.C.C.C.C.C.C.C.C.C.C.C.C.C.C.C.CC(C)C  NA         1
# 678          C.C.C.C.C.C.C.C.C.C.C.C.C.C.C.C1C23CC12C3  NA         1
# 679            C.C.C.C.C.C.C.CC12CC1C2.O.O.O.O.O.O.O.O  NA         1
# 680           C.C.C.C.C.C.C.C.C.C.C.CC(C)C.CC12C3C1C32  NA         1

# %%
print(train_df.tail())
print(train_df.shape)
#print(train_df.head())
# Out:
#                 SMILE  ID  Function
# 741           [AlH2]P  NA         1
# 742            [AsH3]  NA         1
# 743           Cl[Hg]I  NA         1
# 744       C1C23CC12C3  NA         1
# 745  C12C3C45C1C34C25  NA         1
# (746, 3)

# %%
train_dataset = MoleculeDataset(train_df)
# Out:
#  15%|█▌        | 115/746 [00:25<01:45,  5.98it/s][16:26:24] UFFTYPER: Warning: hybridization set to SP3 for atom 20
# [16:26:24] UFFTYPER: Warning: hybridization set to SP3 for atom 20
#  85%|████████▌ | 636/746 [01:22<00:22,  4.93it/s][16:27:21] WARNING: not removing hydrogen atom without neighbors
# [16:27:21] WARNING: not removing hydrogen atom without neighbors
# [16:27:21] WARNING: not removing hydrogen atom without neighbors
# [16:27:21] WARNING: not removing hydrogen atom without neighbors
# [16:27:21] WARNING: not removing hydrogen atom without neighbors
# [16:27:21] WARNING: not removing hydrogen atom without neighbors
# [16:27:21] WARNING: not removing hydrogen atom without neighbors
# [16:27:21] WARNING: not removing hydrogen atom without neighbors
# [16:27:21] WARNING: not removing hydrogen atom without neighbors
# [16:27:21] WARNING: not removing hydrogen atom without neighbors
# [16:27:21] WARNING: not removing hydrogen atom without neighbors
# [16:27:21] WARNING: not removing hydrogen atom without neighbors
# [16:27:21] WARNING: not removing hydrogen atom without neighbors
# [16:27:21] WARNING: not removing hydrogen atom without neighbors
# [16:27:21] WARNING: not removing hydrogen atom without neighbors
# [16:27:21] WARNING: not removing hydrogen atom without neighbors
# [16:27:21] WARNING: not removing hydrogen atom without neighbors
# [16:27:21] WARNING: not removing hydrogen atom without neighbors
# [16:27:21] WARNING: not removing hydrogen atom without neighbors
# [16:27:21] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:27:21] UFFTYPER: Warning: hybridization set to SP3 for atom 1
#  87%|████████▋ | 647/746 [01:23<00:11,  8.96it/s][16:27:22] WARNING: not removing hydrogen atom without neighbors
# [16:27:22] WARNING: not removing hydrogen atom without neighbors
# [16:27:22] WARNING: not removing hydrogen atom without neighbors
# [16:27:22] WARNING: not removing hydrogen atom without neighbors
# [16:27:22] WARNING: not removing hydrogen atom without neighbors
# [16:27:22] WARNING: not removing hydrogen atom without neighbors
# [16:27:22] WARNING: not removing hydrogen atom without neighbors
# [16:27:22] WARNING: not removing hydrogen atom without neighbors
# [16:27:22] WARNING: not removing hydrogen atom without neighbors
# [16:27:22] WARNING: not removing hydrogen atom without neighbors
# [16:27:22] WARNING: not removing hydrogen atom without neighbors
# [16:27:22] WARNING: not removing hydrogen atom without neighbors
# [16:27:22] WARNING: not removing hydrogen atom without neighbors
#  87%|████████▋ | 649/746 [01:23<00:11,  8.21it/s][16:27:22] UFFTYPER: Warning: hybridization set to SP for atom 0
# [16:27:22] UFFTYPER: Unrecognized charge state for atom: 0
# [16:27:22] UFFTYPER: Warning: hybridization set to SP for atom 3
# [16:27:22] UFFTYPER: Unrecognized charge state for atom: 3
#  88%|████████▊ | 654/746 [01:24<00:09,  9.43it/s][16:27:22] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:27:22] UFFTYPER: Warning: hybridization set to SP3 for atom 19
#  88%|████████▊ | 658/746 [01:24<00:08,  9.88it/s][16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
#  89%|████████▉ | 664/746 [01:25<00:06, 11.92it/s][16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
#  89%|████████▉ | 667/746 [01:25<00:07, 11.10it/s][16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
# [16:27:23] WARNING: not removing hydrogen atom without neighbors
#  90%|████████▉ | 669/746 [01:25<00:06, 11.83it/s][16:27:24] WARNING: not removing hydrogen atom without neighbors
# [16:27:24] WARNING: not removing hydrogen atom without neighbors
# [16:27:24] WARNING: not removing hydrogen atom without neighbors
# [16:27:24] WARNING: not removing hydrogen atom without neighbors
# [16:27:24] WARNING: not removing hydrogen atom without neighbors
# [16:27:24] WARNING: not removing hydrogen atom without neighbors
# [16:27:24] WARNING: not removing hydrogen atom without neighbors
# [16:27:24] WARNING: not removing hydrogen atom without neighbors
# [16:27:24] WARNING: not removing hydrogen atom without neighbors
# [16:27:24] WARNING: not removing hydrogen atom without neighbors
# [16:27:24] WARNING: not removing hydrogen atom without neighbors
# [16:27:24] WARNING: not removing hydrogen atom without neighbors
# [16:27:24] WARNING: not removing hydrogen atom without neighbors
# [16:27:24] WARNING: not removing hydrogen atom without neighbors
# [16:27:24] WARNING: not removing hydrogen atom without neighbors
# [16:27:24] WARNING: not removing hydrogen atom without neighbors
# [16:27:24] WARNING: not removing hydrogen atom without neighbors
# [16:27:24] WARNING: not removing hydrogen atom without neighbors
# [16:27:24] WARNING: not removing hydrogen atom without neighbors
#  90%|█████████ | 675/746 [01:27<00:15,  4.68it/s][16:27:25] WARNING: not removing hydrogen atom without neighbors
# [16:27:25] WARNING: not removing hydrogen atom without neighbors
# [16:27:25] WARNING: not removing hydrogen atom without neighbors
# [16:27:25] WARNING: not removing hydrogen atom without neighbors
# [16:27:25] WARNING: not removing hydrogen atom without neighbors
# [16:27:25] WARNING: not removing hydrogen atom without neighbors
# [16:27:25] WARNING: not removing hydrogen atom without neighbors
# [16:27:25] WARNING: not removing hydrogen atom without neighbors
# [16:27:25] WARNING: not removing hydrogen atom without neighbors
# [16:27:25] WARNING: not removing hydrogen atom without neighbors
# [16:27:25] WARNING: not removing hydrogen atom without neighbors
# [16:27:25] WARNING: not removing hydrogen atom without neighbors
# [16:27:25] WARNING: not removing hydrogen atom without neighbors
# [16:27:25] WARNING: not removing hydrogen atom without neighbors
# [16:27:25] WARNING: not removing hydrogen atom without neighbors
# [16:27:25] WARNING: not removing hydrogen atom without neighbors
# [16:27:25] WARNING: not removing hydrogen atom without neighbors
# [16:27:25] WARNING: not removing hydrogen atom without neighbors
#  91%|█████████▏| 681/746 [01:27<00:11,  5.80it/s][16:27:26] UFFTYPER: Warning: hybridization set to SP3 for atom 2
# [16:27:26] UFFTYPER: Warning: hybridization set to SP for atom 4
# [16:27:26] UFFTYPER: Unrecognized charge state for atom: 4
# [16:27:26] UFFTYPER: Warning: hybridization set to SP3 for atom 2
# [16:27:26] UFFTYPER: Warning: hybridization set to SP for atom 4
# [16:27:26] UFFTYPER: Unrecognized charge state for atom: 4
# [16:27:26] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:27:26] UFFTYPER: Unrecognized charge state for atom: 1
# [16:27:26] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:27:26] UFFTYPER: Unrecognized charge state for atom: 1
# [16:27:26] UFFTYPER: Warning: hybridization set to SP for atom 0
# [16:27:26] UFFTYPER: Unrecognized charge state for atom: 0
# [16:27:26] UFFTYPER: Unrecognized atom type: S_6+6 (4)
# [16:27:26] UFFTYPER: Unrecognized atom type: S_5+4 (5)
# [16:27:26] UFFTYPER: Warning: hybridization set to SP for atom 6
# [16:27:26] UFFTYPER: Unrecognized charge state for atom: 6
# [16:27:26] UFFTYPER: Warning: hybridization set to SP for atom 0
# [16:27:26] UFFTYPER: Unrecognized charge state for atom: 0
# [16:27:26] UFFTYPER: Warning: hybridization set to SP for atom 0
# [16:27:26] UFFTYPER: Unrecognized charge state for atom: 0
#  93%|█████████▎| 692/746 [01:28<00:03, 16.35it/s][16:27:26] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:27:26] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:27:26] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:27:26] UFFTYPER: Unrecognized charge state for atom: 0
# [16:27:26] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:27:26] UFFTYPER: Unrecognized charge state for atom: 0
#  94%|█████████▍| 703/746 [01:28<00:01, 28.29it/s]
# Data was None
# Data was None
# [16:27:26] UFFTYPER: Warning: hybridization set to SP for atom 0
# [16:27:26] UFFTYPER: Unrecognized charge state for atom: 0
# [16:27:26] UFFTYPER: Warning: hybridization set to SP for atom 0
# [16:27:26] UFFTYPER: Unrecognized charge state for atom: 0
# [16:27:26] WARNING: not removing hydrogen atom without neighbors
#  95%|█████████▌| 709/746 [01:28<00:01, 28.22it/s]
# Data was None
# Data was None
# [16:27:27] UFFTYPER: Warning: hybridization set to SP for atom 1
# [16:27:27] UFFTYPER: Unrecognized charge state for atom: 1
# [16:27:27] UFFTYPER: Warning: hybridization set to SP for atom 8
# [16:27:27] UFFTYPER: Unrecognized charge state for atom: 8
# [16:27:27] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [16:27:27] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [16:27:27] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [16:27:27] UFFTYPER: Warning: hybridization set to SP for atom 1
# [16:27:27] UFFTYPER: Unrecognized charge state for atom: 1
# [16:27:27] UFFTYPER: Warning: hybridization set to SP for atom 3
# [16:27:27] UFFTYPER: Unrecognized charge state for atom: 3
# [16:27:27] UFFTYPER: Warning: hybridization set to SP for atom 5
# [16:27:27] UFFTYPER: Unrecognized charge state for atom: 5
# [16:27:27] UFFTYPER: Warning: hybridization set to SP for atom 8
# [16:27:27] UFFTYPER: Unrecognized charge state for atom: 8
# [16:27:27] UFFTYPER: Unrecognized charge state for atom: 10
# [16:27:27] UFFTYPER: Unrecognized atom type: As5+3 (10)
# [16:27:27] UFFTYPER: Unrecognized charge state for atom: 11
# [16:27:27] UFFTYPER: Unrecognized atom type: As5+3 (11)
# [16:27:27] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:27:27] UFFTYPER: Warning: hybridization set to SP3 for atom 0
#  96%|█████████▌| 714/746 [01:29<00:01, 17.44it/s]
# Data was None
# Data was None
# [16:27:27] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:27:27] UFFTYPER: Unrecognized charge state for atom: 1
# [16:27:27] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:27:27] UFFTYPER: Unrecognized charge state for atom: 1
# [16:27:27] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:27:27] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:27:27] UFFTYPER: Warning: hybridization set to SP3 for atom 4
# [16:27:27] UFFTYPER: Warning: hybridization set to SP3 for atom 4
# [16:27:27] UFFTYPER: Warning: hybridization set to SP for atom 1
# [16:27:27] UFFTYPER: Unrecognized charge state for atom: 1
# [16:27:27] UFFTYPER: Warning: hybridization set to SP for atom 1
# [16:27:27] UFFTYPER: Unrecognized charge state for atom: 1
# [16:27:27] UFFTYPER: Warning: hybridization set to SP for atom 0
# [16:27:27] UFFTYPER: Unrecognized charge state for atom: 0
# [16:27:27] UFFTYPER: Warning: hybridization set to SP for atom 2
# [16:27:27] UFFTYPER: Unrecognized charge state for atom: 2
# [16:27:27] UFFTYPER: Warning: hybridization set to SP for atom 3
# [16:27:27] UFFTYPER: Unrecognized charge state for atom: 3
#  98%|█████████▊| 732/746 [01:29<00:00, 27.36it/s][16:27:28] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:27:28] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:27:28] UFFTYPER: Warning: hybridization set to SP for atom 2
# [16:27:28] UFFTYPER: Unrecognized charge state for atom: 2
# [16:27:28] UFFTYPER: Warning: hybridization set to SP for atom 2
# [16:27:28] UFFTYPER: Unrecognized charge state for atom: 2
# [16:27:28] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:27:28] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# 100%|██████████| 746/746 [01:29<00:00,  8.34it/s]
# Data was None

# %%
from torch_geometric.loader import DataLoader #fixes bug used by other library loader for graphRNN portion

# Create DataLoaders
batch_size = 8 #was 32
print(f"Number of training samples: {len(train_dataset)}")
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

criterion = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
model = HEGNNClassifier(heg_nn, hidden_dim).to(device)
# Out:
# Number of training samples: 739

# %%
# Training loop execution
num_epochs = 15 #was 20
for epoch in range(1, num_epochs + 1):
    train_loss = train(model, train_loader)
    val_loss, val_preds, val_labels = evaluate(model, val_loader)

    val_accuracy = get_accuracy(val_preds, val_labels)
    
    print(f'Epoch {epoch}, Train Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}')
# Out:
# Epoch 1, Train Loss: 0.7460, Validation Loss: 0.6845, Validation Accuracy: 0.6541
# Epoch 2, Train Loss: 0.6870, Validation Loss: 0.6882, Validation Accuracy: 0.5865
# Epoch 3, Train Loss: 0.6819, Validation Loss: 0.6864, Validation Accuracy: 0.6015
# Epoch 4, Train Loss: 0.6865, Validation Loss: 0.6865, Validation Accuracy: 0.5940
# Epoch 5, Train Loss: 0.6838, Validation Loss: 0.6904, Validation Accuracy: 0.5038
# Epoch 6, Train Loss: 0.6766, Validation Loss: 0.6922, Validation Accuracy: 0.5113
# Epoch 7, Train Loss: 0.6846, Validation Loss: 0.6919, Validation Accuracy: 0.4962
# Epoch 8, Train Loss: 0.6785, Validation Loss: 0.6942, Validation Accuracy: 0.4962
# Epoch 9, Train Loss: 0.6752, Validation Loss: 0.6936, Validation Accuracy: 0.4887
# Epoch 10, Train Loss: 0.6678, Validation Loss: 0.7033, Validation Accuracy: 0.5564
# Epoch 11, Train Loss: 0.6636, Validation Loss: 0.7139, Validation Accuracy: 0.5338
# Epoch 12, Train Loss: 0.6760, Validation Loss: 0.6898, Validation Accuracy: 0.5263
# Epoch 13, Train Loss: 0.6764, Validation Loss: 0.6932, Validation Accuracy: 0.5038
# Epoch 14, Train Loss: 0.6723, Validation Loss: 0.6884, Validation Accuracy: 0.5489
# Epoch 15, Train Loss: 0.6675, Validation Loss: 0.6799, Validation Accuracy: 0.5564

# %%
# Evaluate the full model on the test set and plot ROC curve
model.eval()
all_preds = []
all_labels = []
with torch.no_grad():
    for data in test_loader:
        data = data.to(device)
        out, _ = model(data)
        preds = torch.sigmoid(out).cpu().numpy()
        labels = data.y.cpu().numpy()
        all_preds.extend(preds)
        all_labels.extend(labels)

accuracy = get_accuracy(all_preds, all_labels)
print(f"Testing accuracy: {accuracy:.4f}")

# Compute ROC curve and AUC
fpr, tpr, thresholds = roc_curve(all_labels, all_preds)

roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, label=f'Full Model ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC - Full Model')
plt.legend(loc='lower right')
plt.show()
# Out:
# Testing accuracy: 0.6087

# %%
all_preds[0:50]
# Out:
# [array([0.4278514], dtype=float32),
#  array([0.20645198], dtype=float32),
#  array([0.52078533], dtype=float32),
#  array([0.3949552], dtype=float32),
#  array([0.4092878], dtype=float32),
#  array([0.48046204], dtype=float32),
#  array([0.58529466], dtype=float32),
#  array([0.3178452], dtype=float32),
#  array([0.39191595], dtype=float32),
#  array([0.39591295], dtype=float32),
#  array([0.5743747], dtype=float32),
#  array([0.38386846], dtype=float32),
#  array([0.27179182], dtype=float32),
#  array([0.33592415], dtype=float32),
#  array([0.61407787], dtype=float32),
#  array([0.55565685], dtype=float32),
#  array([0.46069518], dtype=float32),
#  array([0.6221735], dtype=float32),
#  array([0.39912936], dtype=float32),
#  array([0.42704973], dtype=float32),
#  array([0.23207939], dtype=float32),
#  array([0.6522679], dtype=float32),
#  array([0.2894271], dtype=float32),
#  array([0.5113704], dtype=float32),
#  array([0.3977211], dtype=float32),
#  array([0.45634085], dtype=float32),
#  array([0.4378986], dtype=float32),
#  array([0.41054145], dtype=float32),
#  array([0.56053764], dtype=float32),
#  array([0.51976866], dtype=float32),
#  array([0.6131419], dtype=float32),
#  array([0.5026783], dtype=float32),
#  array([0.571443], dtype=float32),
#  array([0.63190395], dtype=float32),
#  array([0.37709826], dtype=float32),
#  array([0.50227064], dtype=float32),
#  array([0.57993567], dtype=float32),
#  array([0.43893504], dtype=float32),
#  array([0.50552547], dtype=float32),
#  array([0.49906656], dtype=float32),
#  array([0.35741702], dtype=float32),
#  array([0.47456336], dtype=float32),
#  array([0.5383038], dtype=float32),
#  array([0.5169702], dtype=float32),
#  array([0.5187566], dtype=float32),
#  array([0.4348456], dtype=float32),
#  array([0.42184785], dtype=float32),
#  array([0.30403054], dtype=float32),
#  array([0.20471008], dtype=float32),
#  array([0.2867274], dtype=float32)]
